# %%
import pandas as pd
from pandas.io import gbq

from sklearn.cluster import DBSCAN
from sklearn import metrics

# %%
user_data = gbq.read_gbq('SELECT * FROM `umg-comm-tech-dev.adhoc.disapora_user_stats2`', 
                         project_id='umg-comm-tech-dev', dialect='standard')

# %%
user_data.describe(include='all')
# Out:
#                   f0_ user_dma_number user_dma_name user_region_code  \
# count   532883.000000          532883        532883           532883
# unique            NaN             425           211                1
# top               NaN             803   Los Angeles
# freq              NaN           49758         49758           532883
# mean        18.959303             NaN           NaN              NaN
# std        154.688909             NaN           NaN              NaN
# min          1.000000             NaN           NaN              NaN
# 25%          1.000000             NaN           NaN              NaN
# 50%          2.000000             NaN           NaN              NaN
# 75%          7.000000             NaN           NaN              NaN
# max      26789.000000             NaN           NaN              NaN
#
#        user_postal_code user_gender user_age_group    stream_source  \
# count            532883      532883         532883           532883
# unique              925           3              9                9
# top                            male          18-24  others_playlist
# freq              86950      282362         206854           160897
# mean                NaN         NaN            NaN              NaN
# std                 NaN         NaN            NaN              NaN
# min                 NaN         NaN            NaN              NaN
# 25%                 NaN         NaN            NaN              NaN
# 50%                 NaN         NaN            NaN              NaN
# 75%                 NaN         NaN            NaN              NaN
# max                 NaN         NaN            NaN              NaN
#
#        device_type os_name partner_product partner_access_type  \
# count       532883  532883          532883              532883
# unique           8       7              14                   3
# top     cell phone     iOS                             premium
# freq        304675  235866          275613              416124
# mean           NaN     NaN             NaN                 NaN
# std            NaN     NaN             NaN                 NaN
# min            NaN     NaN             NaN                 NaN
# 25%            NaN     NaN             NaN                 NaN
# 50%            NaN     NaN             NaN                 NaN
# 75%            NaN     NaN             NaN                 NaN
# max            NaN     NaN             NaN                 NaN
#
#        partner_user_type revenue_model consumer_group consumer_group_detail  \
# count             532883        532883         532883                532883
# unique                 5             2              3                     8
# top                 paid       Premium           Paid              Standard
# freq              397865        416230         402701                164743
# mean                 NaN           NaN            NaN                   NaN
# std                  NaN           NaN            NaN                   NaN
# min                  NaN           NaN            NaN                   NaN
# 25%                  NaN           NaN            NaN                   NaN
# 50%                  NaN           NaN            NaN                   NaN
# 75%                  NaN           NaN            NaN                   NaN
# max                  NaN           NaN            NaN                   NaN
#
#        engagement_style
# count            532883
# unique                2
# top        Lean Forward
# freq             268671
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %%
user_data = user_data.rename(columns={'f0_':'user_count'})

# %%
user_data.consumer_group_detail.unique()
# Out:
# array(['Family', 'Standard', 'Discounted', 'Ad-Funded', 'Introductory',
#        'Trial - 30 Days - Credit Card', 'Trial - 7 Days - No Credit Card',
#        'Bundle'], dtype=object)

# %%
user_data.columns
# Out:
# Index(['user_count', 'user_dma_number', 'user_dma_name', 'user_region_code',
#        'user_postal_code', 'user_gender', 'user_age_group', 'stream_source',
#        'device_type', 'os_name', 'partner_product', 'partner_access_type',
#        'partner_user_type', 'revenue_model', 'consumer_group',
#        'consumer_group_detail', 'engagement_style'],
#       dtype='object')

# %%
cols = ['user_count', 'user_dma_number', 'user_dma_name',
       'user_postal_code', 'user_gender', 'user_age_group', 'device_type', 'os_name']

# %%
user_data_agg = user_data[cols]

# %%
user_data_gb = user_data_agg.groupby(by = ['user_dma_number', 'user_dma_name',
       'user_postal_code', 'user_gender', 'user_age_group', 'device_type', 'os_name'])

# %%
user_data_final = user_data_gb.user_count.sum().reset_index().sort_values(by='user_count', ascending=False)

# %%
user_data_final.to_csv('user_data_summary.csv', index=False)

# %%
user_data_final.head()
# Out:
#        user_dma_number               user_dma_name user_postal_code  \
# 807                501                    New York
# 131279             803                 Los Angeles
# 141307             807  San Francisco-Oak-San Jose
# 887                501                    New York
# 141393             807  San Francisco-Oak-San Jose
#
#        user_gender user_age_group device_type os_name  user_count
# 807         female          25-34  cell phone     iOS       66299
# 131279      female          25-34  cell phone     iOS       60423
# 141307      female          25-34  cell phone     iOS       56535
# 887           male          25-34  cell phone     iOS       54783
# 141393        male          25-34  cell phone     iOS       54372

# %%
user_data_post = user_data_final.groupby(by=['user_postal_code'])

# %%
by_post = user_data_post.user_count.sum().reset_index().sort_values(by='user_count', ascending=False)

# %%
by_post.to_csv('by_postcode_summary.csv')

# %%
all_users = by_post.user_count.sum()

# %%
by_post['user_perc'] = by_post.user_count/all_users
by_post.head()
# Out:
#      user_postal_code user_gender user_age_group device_type os_name  \
# 7571              123      female          25-34  cell phone     iOS
# 7582              123      female          35-44  cell phone     iOS
# 7559              123      female          18-24  cell phone     iOS
# 5451              100      female          25-34  cell phone     iOS
# 7657              123        male          25-34  cell phone     iOS
#
#       user_count  user_perc
# 7571       65844   0.011432
# 7582       51186   0.008887
# 7559       49742   0.008636
# 5451       41712   0.007242
# 7657       37448   0.006502

# %%
by_post.shape
# Out:
# (50995, 7)

# %%
by_dma_post = user_data_agg.groupby(by=['user_dma_number', 'user_dma_name','user_postal_code']).user_count.sum().reset_index().sort_values(by='user_count', ascending=False)

# %%
by_dma_post['user_%'] = by_dma_post.user_count/all_users*100
by_dma_post
# Out:
#       user_dma_number               user_dma_name user_postal_code  \
# 23379             803                 Los Angeles
# 24143             807  San Francisco-Oak-San Jose
# 162               501                    New York
# 27965         Unknown
# 24029             803                 Los Angeles              917
# 24780             807  San Francisco-Oak-San Jose              941
# 264               501                    New York              112
# 25028             819              Seattle-Tacoma
# 252               501                    New York              100
# 1787              506         Boston (Manchester)
# 24784             807  San Francisco-Oak-San Jose              945
# 12869             602                     Chicago
# 265               501                    New York              113
# 3020              511   Washington, DC (Hagrstwn)
# 24779             807  San Francisco-Oak-San Jose              940
# 23484             803                 Los Angeles              123
# 24245             807  San Francisco-Oak-San Jose              123
# 954               504                Philadelphia
# 15682             623            Dallas-Ft. Worth
# 24013             803                 Los Angeles              900
# 275               501                    New York              123
# 25540             819              Seattle-Tacoma              980
# 26658             862    Sacramnto-Stkton-Modesto
# 28043         Unknown                                          100
# 14990             618                     Houston
# 24790             807  San Francisco-Oak-San Jose              951
# 5313              524                     Atlanta
# 1803              506         Boston (Manchester)              021
# 25541             819              Seattle-Tacoma              981
# 13293             602                     Chicago              606
# ...               ...                         ...              ...
# 12187             577  Wilkes Barre-Scranton-Hztn              139
# 12185             577  Wilkes Barre-Scranton-Hztn              137
# 12179             577  Wilkes Barre-Scranton-Hztn              105
# 12178             577  Wilkes Barre-Scranton-Hztn              104
# 21801             753          Phoenix (Prescott)              431
# 21756             753          Phoenix (Prescott)              295
# 12177             577  Wilkes Barre-Scranton-Hztn              101
# 12174             577  Wilkes Barre-Scranton-Hztn              087
# 21804             753          Phoenix (Prescott)              439
# 12173             577  Wilkes Barre-Scranton-Hztn              085
# 12172             577  Wilkes Barre-Scranton-Hztn              080
# 21808             753          Phoenix (Prescott)              451
# 21790             753          Phoenix (Prescott)              373
# 12189             577  Wilkes Barre-Scranton-Hztn              145
# 21788             753          Phoenix (Prescott)              370
# 21786             753          Phoenix (Prescott)              358
# 21785             753          Phoenix (Prescott)              357
# 21784             753          Phoenix (Prescott)              352
# 12193             577  Wilkes Barre-Scranton-Hztn              168
# 21781             753          Phoenix (Prescott)              341
# 21780             753          Phoenix (Prescott)              339
# 12197             577  Wilkes Barre-Scranton-Hztn              172
# 12198             577  Wilkes Barre-Scranton-Hztn              174
# 21773             753          Phoenix (Prescott)              330
# 3661              512                   Baltimore              020
# 12212             577  Wilkes Barre-Scranton-Hztn              189
# 21765             753          Phoenix (Prescott)              319
# 12216             577  Wilkes Barre-Scranton-Hztn              194
# 21760             753          Phoenix (Prescott)              301
# 28660         Unknown                                          999
#
#        user_count     user_%
# 23379      883501  15.339004
# 24143      745386  12.941104
# 162        683728  11.870622
# 27965      370687   6.435725
# 24029      174799   3.034793
# 24780      150623   2.615058
# 264        149242   2.591082
# 25028      144293   2.505159
# 252        142969   2.482173
# 1787       131195   2.277757
# 24784      115009   1.996742
# 12869      112541   1.953893
# 265        109049   1.893267
# 3020       108178   1.878145
# 24779      105051   1.823855
# 23484       98681   1.713261
# 24245       95199   1.652808
# 954         94740   1.644839
# 15682       94661   1.643468
# 24013       93886   1.630013
# 275         93109   1.616523
# 25540       76048   1.320316
# 26658       71009   1.232831
# 28043       68624   1.191423
# 14990       67724   1.175798
# 24790       67151   1.165850
# 5313        66066   1.147012
# 1803        63781   1.107341
# 25541       63063   1.094875
# 13293       54541   0.946920
# ...           ...        ...
# 12187           1   0.000017
# 12185           1   0.000017
# 12179           1   0.000017
# 12178           1   0.000017
# 21801           1   0.000017
# 21756           1   0.000017
# 12177           1   0.000017
# 12174           1   0.000017
# 21804           1   0.000017
# 12173           1   0.000017
# 12172           1   0.000017
# 21808           1   0.000017
# 21790           1   0.000017
# 12189           1   0.000017
# 21788           1   0.000017
# 21786           1   0.000017
# 21785           1   0.000017
# 21784           1   0.000017
# 12193           1   0.000017
# 21781           1   0.000017
# 21780           1   0.000017
# 12197           1   0.000017
# 12198           1   0.000017
# 21773           1   0.000017
# 3661            1   0.000017
# 12212           1   0.000017
# 21765           1   0.000017
# 12216           1   0.000017
# 21760           1   0.000017
# 28660           1   0.000017
#
# [28661 rows x 5 columns]

# %%
by_dma_post.to_csv('dma_postcode_summary.csv')

# %%
by_age_gender = user_data_agg.groupby(by=['user_gender', 'user_age_group']).user_count.sum().reset_index().sort_values(by='user_count', ascending=False)

# %%
by_age_gender['user_%'] = by_age_gender.user_count/all_users*100
by_age_gender.to_csv('age_gender_summary.csv')

# %%
by_device_os = user_data_agg.groupby(by=['device_type', 'os_name']).user_count.sum().reset_index().sort_values(by='user_count', ascending=False)

# %%
by_device_os['user_%'] = by_device_os.user_count/all_users*100
by_device_os.to_csv('device_os_summary.csv')
