# %%
import pandas as pd
from pandas.io import gbq

# %%
data = pd.read_csv('/Users/meshchd/Downloads/export_playlists_2019_05_28_15_41_08.csv', header=None)
data.head()
# Out:
#    0    1          2            3   \
# 0   1  NaN  uDiscover          60s
# 1   2  NaN  uDiscover   Prog Rocks
# 2   3  NaN  uDiscover          50s
# 3   4  NaN  uDiscover    Rock Hits
# 4   5  NaN  uDiscover  Heavy Metal
#
#                                                   4   \
# 0  Del Shannon;Patsy Cline;Rock;Party;Decades;Cat...
# 1  Gentle Giant;Camel;Steven Wilson;Rock;Driving;...
# 2                 Rock;Happy;Party;Decades;Catalogue
# 3  The Rolling Stones;Queen;Fats Domino;Tom Petty...
# 4  Metallica;Rob Zombie;Metal;Angry;Driving;Worko...
#
#                          5                            6        7   \
# 0  theresa.lopez@umusic.com                          NaN   Weekly
# 1  theresa.lopez@umusic.com  Morenike.Ariyibi@umusic.com  Monthly
# 2  theresa.lopez@umusic.com                          NaN   Weekly
# 3                       NaN                          NaN   Weekly
# 4  theresa.lopez@umusic.com  Morenike.Ariyibi@umusic.com  Monthly
#
# ...

# %%
data.iloc[:,9]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#        ...
# 4223    NaN
# 4224    NaN
# 4225    NaN
# 4226    NaN
# 4227    NaN
# 4228    NaN
# 4229    NaN
# 4230    NaN
# 4231    NaN
# 4232    NaN
# 4233    NaN
# 4234    NaN
# 4235    NaN
# 4236    NaN
# 4237    NaN
# 4238    NaN
# 4239    NaN
# 4240    NaN
# 4241    NaN
# 4242    NaN
# 4243    NaN
# 4244    NaN
# 4245    NaN
# 4246    NaN
# 4247    NaN
# 4248    NaN
# 4249    NaN
# 4250    NaN
# 4251    NaN
# 4252    NaN
# Name: itunes_link, Length: 4253, dtype: object

# %%
col_names = {
    2:'brand',
    3:'theme',
    4:'tags',
    5:'email1',
    6:'email2',
    7:'frequency',
    8:'spotify_link',
    9:'deezer_link',
    10:'napster_link',
    11:'itunes_link',
    12:'youtube_link',
    16:'tags2',
    18:'genre'
}
cols_drop = [x for x in range(23) if x not in col_names.keys()]
data = data.drop(columns=cols_drop)
data = data.rename(columns=col_names)

data.head()
# Out:
#        brand        theme                                               tags  \
# 0  uDiscover          60s  Del Shannon;Patsy Cline;Rock;Party;Decades;Cat...
# 1  uDiscover   Prog Rocks  Gentle Giant;Camel;Steven Wilson;Rock;Driving;...
# 2  uDiscover          50s                 Rock;Happy;Party;Decades;Catalogue
# 3  uDiscover    Rock Hits  The Rolling Stones;Queen;Fats Domino;Tom Petty...
# 4  uDiscover  Heavy Metal  Metallica;Rob Zombie;Metal;Angry;Driving;Worko...
#
#                      email1                       email2 frequency  \
# 0  theresa.lopez@umusic.com                          NaN    Weekly
# 1  theresa.lopez@umusic.com  Morenike.Ariyibi@umusic.com   Monthly
# 2  theresa.lopez@umusic.com                          NaN    Weekly
# 3                       NaN                          NaN    Weekly
# 4  theresa.lopez@umusic.com  Morenike.Ariyibi@umusic.com   Monthly
#
#                                         spotify_link  \
# ...

# %%
data.describe(include='all')
# Out:
#             brand                               theme       tags  \
# count        4087                                4087       1611
# unique         84                                4026       1064
# top     uDiscover  Your personalised holiday playlist  Christian
# freq         1015                                  12        110
#
#                          email1                       email2 frequency  \
# count                      3246                          432      2166
# unique                       75                           22         3
# top     chikka.k.moyo@gmail.com  Morenike.Ariyibi@umusic.com    Weekly
# freq                       1021                          204      1326
#
#                                              spotify_link  \
# count                                                4009
# unique                                               4009
# top     https://open.spotify.com/user/spotify/playlist...
# ...

# %%
gbq.to_gbq(data, 'create.playlists_extract', project_id='umg-comm-tech-dev', if_exists='replace')
# Out:
# 1it [00:04,  4.38s/it]
