# %%
import numpy as np
import pandas as pd
from pandas.io import gbq

import seaborn as sns
import matplotlib.pyplot as plt

import re
from collections import Counter
import itertools

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.ensemble import IsolationForest, RandomForestClassifier

# %matplotlib inline

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/daria/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
### Confusion matrix graph function

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True popular')
    plt.xlabel('Predicted popular')
    plt.show()

# %%
### ROC curve plotting function

def plot_roc(mod, X, y, varname):
    mod.fit(X, y)
    y_pp = mod.predict_proba(X)[:, 1]
    fpr_, tpr_, _ = roc_curve(y, y_pp)
    auc_ = auc(fpr_, tpr_)
    acc_ = np.abs(0.5 - np.mean(y)) + 0.5
    
    fig, axr = plt.subplots(figsize=(8,7))

    axr.plot(fpr_, tpr_, label='ROC (area = %0.2f)' % auc_,
             color='darkred', linewidth=4,
             alpha=0.7)
    axr.plot([0, 1], [0, 1], color='grey', ls='dashed',
             alpha=0.9, linewidth=4, label='baseline accuracy = %0.2f' % acc_)

    axr.set_xlim([-0.05, 1.05])
    axr.set_ylim([0.0, 1.05])
    axr.set_xlabel('false positive rate', fontsize=16)
    axr.set_ylabel('true positive rate', fontsize=16)
    axr.set_title(varname+' vs. not ROC curve\n', fontsize=20)

    axr.legend(loc="lower right", fontsize=12)

    plt.show()

# %%
### Classification metrics report function

def classification_metrics(model, x_test_set, y_test_set, predictions):
    plot_confusion_matrix(confusion_matrix(y_test_set, predictions), classes=[0,1,2])
    print("Accuracy score: "), print(accuracy_score(y_test_set, predictions))
    #print("Baseline: "), print(max(np.mean(y_test_set),(1-np.mean(y_test_set))))
    print(classification_report(y_test_set, predictions))
    #plot_roc(model, x_test_set, y_test_set, 'popularity')

# %%
release_schedule = pd.read_clipboard()

# %%
release_schedule.head()

# %%
release_schedule.to_csv('release_schedule.csv', index=False)

# %%
release_schedule.UPC.unique()

# %%
sources = ['7 Digital',
'7digital Limited',
'Apple',
'iTunes',
'Amazon',
'Deezer',
'Spotify',
'YouTube',
'Google',
'Napster by Rhapsody']

# %%
swift_sql = "SELECT * FROM `umg-comm-tech-dev.fixed_playlists.stats_swift_consumption`"
data = gbq.read_gbq(query=swift_sql, project_id='umg-comm-tech-dev', dialect='standard')
data.head()

# %%
by_upc_account_year_month = data.groupby(by=['upc','sub_account_name','year','month'])

# %%
summed_data = by_upc_account_year_month.sum().reset_index()

# %%
summed_data.head()

# %%
summed_data.shape

# %%
summed_data.to_csv('upc_account_date.csv')

# %%
summed_data = pd.read_csv('upc_account_date.csv', index_col='Unnamed: 0', dtype={'upc':str})
release_schedule = pd.read_csv('release_schedule.csv', dtype={'UPC':str})

# %%
release_schedule.UPC.dtype
# Out:
# dtype('O')

# %%
summed_data.upc.dtype
# Out:
# dtype('O')

# %%
summed_data.head()
# Out:
#               upc sub_account_name  year  month  euro_amount  total_streams
# 0  00600406836304           Deezer  2018      9        0.026              6
# 1  00600406836304           Deezer  2018     10        0.019              4
# 2  00600406836304           Deezer  2018     11        0.005              1
# 3  00600406836304           Deezer  2018     12        0.010              2
# 4  00600406836304           Deezer  2019      1        0.005              1

# %%
summed_data = summed_data.merge(release_schedule, how='left', left_on = 'upc', right_on = 'UPC')
summed_data = summed_data.drop(columns = 'UPC')

# %%
summed_data['month'] = [str(x) if x > 9 else '0'+str(x) for x in summed_data.month]

# %%
summed_data['year_month'] = [str(x)+str(y) for x,y in zip(summed_data.year, summed_data.month)]
summed_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams  \
# 0  00600406836304           Deezer  2018    09        0.026              6
# 1  00600406836304           Deezer  2018    10        0.019              4
# 2  00600406836304           Deezer  2018    11        0.005              1
# 3  00600406836304           Deezer  2018    12        0.010              2
# 4  00600406836304           Deezer  2019    01        0.005              1
#
#   Release Date          Title/Theme year_month
# 0     5/4/2018  Blues For Breakfast     201809
# 1     5/4/2018  Blues For Breakfast     201810
# 2     5/4/2018  Blues For Breakfast     201811
# 3     5/4/2018  Blues For Breakfast     201812
# 4     5/4/2018  Blues For Breakfast     201901

# %%
by_upc_account = summed_data.groupby(by=['upc','sub_account_name']).year_month.nunique().describe()

# %%
by_upc_account
# Out:
# count   1579.000
# mean       9.103
# std        6.384
# min        1.000
# 25%        4.000
# 50%        8.000
# 75%       13.000
# max       53.000
# Name: year_month, dtype: float64

# %%
summed_data = summed_data.rename(columns={'Release Date':'release_date', 'Title/Theme':'title_theme'})

# %%
summed_data.groupby(by=['upc','sub_account_name']).total_streams.mean().describe()
# Out:
# count       1579.000
# mean       55096.678
# std       401622.110
# min            0.000
# 25%          817.208
# 50%         5666.769
# 75%        26206.133
# max     13665753.438
# Name: total_streams, dtype: float64

# %%
summed_data['release_date'] = pd.to_datetime(summed_data['release_date'])

# %%
summed_data['reports_date'] = pd.to_datetime(summed_data[['year', 'month']].assign(day=1))
summed_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams  \
# 0  00600406836304           Deezer  2018    09        0.026              6
# 1  00600406836304           Deezer  2018    10        0.019              4
# 2  00600406836304           Deezer  2018    11        0.005              1
# 3  00600406836304           Deezer  2018    12        0.010              2
# 4  00600406836304           Deezer  2019    01        0.005              1
#
#   release_date          title_theme year_month reports_date
# 0   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 1   2018-05-04  Blues For Breakfast     201810   2018-10-01
# 2   2018-05-04  Blues For Breakfast     201811   2018-11-01
# 3   2018-05-04  Blues For Breakfast     201812   2018-12-01
# 4   2018-05-04  Blues For Breakfast     201901   2019-01-01

# %%
summed_data['playlist_lifetime_months'] = ((summed_data.reports_date - summed_data.release_date)/np.timedelta64(1, 'M'))

# %%
summed_data['playlist_lifetime_months'] = np.round(summed_data.playlist_lifetime_months, decimals=0)
summed_data['playlist_lifetime_months'] = summed_data['playlist_lifetime_months'].fillna(0)
summed_data['playlist_lifetime_months'] = [int(x) for x in summed_data.playlist_lifetime_months]

# %%
summed_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams  \
# 0  00600406836304           Deezer  2018    09        0.026              6
# 1  00600406836304           Deezer  2018    10        0.019              4
# 2  00600406836304           Deezer  2018    11        0.005              1
# 3  00600406836304           Deezer  2018    12        0.010              2
# 4  00600406836304           Deezer  2019    01        0.005              1
#
#   release_date          title_theme year_month reports_date  \
# 0   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 1   2018-05-04  Blues For Breakfast     201810   2018-10-01
# 2   2018-05-04  Blues For Breakfast     201811   2018-11-01
# 3   2018-05-04  Blues For Breakfast     201812   2018-12-01
# 4   2018-05-04  Blues For Breakfast     201901   2019-01-01
#
#    playlist_lifetime_months
# 0                         4
# 1                         5
# 2                         6
# 3                         7
# 4                         8

# %%
max_streams = summed_data.groupby(by=['upc']).total_streams.max().reset_index()

# %%
print(summed_data.groupby(by=['upc']).total_streams.max().quantile(0.25))
print(summed_data.groupby(by=['upc']).total_streams.max().quantile(0.75))
# Out:
# 33445.0
# 299736.0

# %%
max_streams['quantile'] = ''

quant_25 = summed_data.groupby(by=['upc']).total_streams.max().quantile(0.25)
quant_75 = summed_data.groupby(by=['upc']).total_streams.max().quantile(0.75)

for i in range(max_streams.shape[0]):
    if max_streams['total_streams'][i] > quant_75:
        max_streams['quantile'][i] = 'most_popular'
    elif max_streams['total_streams'][i] < quant_25:
        max_streams['quantile'][i] = 'least_popular'
    else:
        max_streams['quantile'][i] = 'middle_popular'
        
max_streams.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               upc  total_streams        quantile
# 0  00600406836304           7715   least_popular
# 1  00600406836311           9265   least_popular
# 2  00600406836335              1   least_popular
# 3  00600406836342          41162  middle_popular
# 4  00600406836359          27292   least_popular

# %%
summed_data = summed_data.merge(max_streams, how='left', on='upc')

# %%
summed_data = summed_data.rename(columns={'total_streams_y':'max_monthly_streams'})
summed_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams_x  \
# 0  00600406836304           Deezer  2018    09        0.026                6
# 1  00600406836304           Deezer  2018    10        0.019                4
# 2  00600406836304           Deezer  2018    11        0.005                1
# 3  00600406836304           Deezer  2018    12        0.010                2
# 4  00600406836304           Deezer  2019    01        0.005                1
#
#   release_date          title_theme year_month reports_date  \
# 0   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 1   2018-05-04  Blues For Breakfast     201810   2018-10-01
# 2   2018-05-04  Blues For Breakfast     201811   2018-11-01
# 3   2018-05-04  Blues For Breakfast     201812   2018-12-01
# 4   2018-05-04  Blues For Breakfast     201901   2019-01-01
#
#    playlist_lifetime_months  max_monthly_streams     quantile_x  \
# 0                         4                 7715  least_popular
# 1                         5                 7715  least_popular
# 2                         6                 7715  least_popular
# 3                         7                 7715  least_popular
# 4                         8                 7715  least_popular
#
#    total_streams     quantile_y
# 0           7715  least_popular
# 1           7715  least_popular
# 2           7715  least_popular
# 3           7715  least_popular
# 4           7715  least_popular

# %%
gbq.to_gbq(summed_data, 'fixed_playlists.stats_swift_consumption', if_exists='replace', 
           project_id='umg-comm-tech-dev')
# Out:
# 1it [00:00,  2.68it/s]

# %%
test = summed_data[summed_data.upc=='00602567171706']

# %%
test
# Out:
#                  upc     sub_account_name  year month  euro_amount  \
# 9728  00602567171706               Amazon  2017    12       19.203
# 9729  00602567171706               Amazon  2018    01       40.505
# 9730  00602567171706               Amazon  2018    02       48.702
# 9731  00602567171706               Amazon  2018    03       25.363
# 9732  00602567171706               Amazon  2018    04       26.413
# 9733  00602567171706               Amazon  2018    05       28.137
# 9799          35664   2017-12-01   90's Rock     201901   2019-01-01
# 9800          41244   2017-12-01   90's Rock     201711   2017-11-01
# 9801         270642   2017-12-01   90's Rock     201801   2018-01-01
# 9802         251631   2017-12-01   90's Rock     201802   2018-02-01
# 9803              1   2017-12-01   90's Rock     201803   2018-03-01
# 9804             27   2017-12-01   90's Rock     201806   2018-06-01
# 9805           4572   2017-12-01   90's Rock     201807   2018-07-01
# 9806            187   2017-12-01   90's Rock     201808   2018-08-01
# 9807             95   2017-12-01   90's Rock     201809   2018-09-01
# 9808             33   2017-12-01   90's Rock     201810   2018-10-01
#
#       playlist_lifetime_months  max_monthly_streams popularity_quantile
# 9728                         0               900277        most_popular
# 9729                         1               900277        most_popular
# 9730                         2               900277        most_popular
# 9731                         3               900277        most_popular
# 9732                         4               900277        most_popular
# 9733                         5               900277        most_popular
# 9734                         6               900277        most_popular
# 9735                         7               900277        most_popular
# 9736                         8               900277        most_popular
# 9737                        -1               900277        most_popular
# 9738                         0               900277        most_popular
# 9739                         1               900277        most_popular
# 9740                         2               900277        most_popular
# 9741                         3               900277        most_popular
# 9742                         4               900277        most_popular
# 9743                         5               900277        most_popular
# 9744                         6               900277        most_popular
# 9745                         7               900277        most_popular
# 9746                         8               900277        most_popular
# 9747                         9               900277        most_popular
# 9748                         0               900277        most_popular
# 9749                         1               900277        most_popular
# 9750                         2               900277        most_popular
# 9751                         3               900277        most_popular
# 9752                         4               900277        most_popular
# 9753                         5               900277        most_popular
# 9754                         6               900277        most_popular
# 9755                         7               900277        most_popular
# 9756                         8               900277        most_popular
# 9757                         9               900277        most_popular
# ...                        ...                  ...                 ...
# 9779                         3               900277        most_popular
# 9780                         4               900277        most_popular
# 9781                         5               900277        most_popular
# 9782                         6               900277        most_popular
# 9783                         7               900277        most_popular
# 9784                         8               900277        most_popular
# 9785                        -1               900277        most_popular
# 9786                         0               900277        most_popular
# 9787                         1               900277        most_popular
# 9788                         2               900277        most_popular
# 9789                         3               900277        most_popular
# 9790                         4               900277        most_popular
# 9791                         5               900277        most_popular
# 9792                         6               900277        most_popular
# 9793                         7               900277        most_popular
# 9794                         8               900277        most_popular
# 9795                         9               900277        most_popular
# 9796                        10               900277        most_popular
# 9797                        11               900277        most_popular
# 9798                        12               900277        most_popular
# 9799                        13               900277        most_popular
# 9800                        -1               900277        most_popular
# 9801                         1               900277        most_popular
# 9802                         2               900277        most_popular
# 9803                         3               900277        most_popular
# 9804                         6               900277        most_popular
# 9805                         7               900277        most_popular
# 9806                         8               900277        most_popular
# 9807                         9               900277        most_popular
# 9808                        10               900277        most_popular
#
# [81 rows x 13 columns]

# %%
sns.relplot(x="playlist_lifetime_months", y="total_streams",
            hue="sub_account_name",
            height=5, aspect=.75, facet_kws=dict(sharex=False),
            kind="line", legend="full", data=test)

# %%
df1 = summed_data.groupby(by=['popularity_quantile','sub_account_name','playlist_lifetime_months']).total_streams.mean().reset_index()
df2=df1[df1.playlist_lifetime_months>-10]

# %%
summed_data.sub_account_name.unique()
# Out:
# array(['Deezer', 'Spotify', 'Google', '7 Digital', 'Amazon', 'Apple',
#        'Napster by Rhapsody', 'YouTube', '7digital Limited', 'iTunes'],
#       dtype=object)

# %%
final_partners = ['Deezer', 'Spotify', 'Google', 'Amazon', 'Apple',
       'Napster by Rhapsody', 'YouTube']
df3 = df2[df2.sub_account_name.isin(final_partners)]

# %%
df3.head()
# Out:
#   popularity_quantile sub_account_name  playlist_lifetime_months  \
# 5       least_popular           Amazon                        -1
# 6       least_popular           Amazon                         0
# 7       least_popular           Amazon                         1
# 8       least_popular           Amazon                         2
# 9       least_popular           Amazon                         3
#
#    total_streams
# 5       2472.000
# 6        348.333
# 7        294.200
# 8        241.667
# 9        194.200

# %%
df3 = df3.rename(columns={'total_streams':'monthly_streams'})

# %%
g = sns.relplot(x="playlist_lifetime_months", y="monthly_streams",
            hue="sub_account_name", col='popularity_quantile',
            height=7, aspect=.75, facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df3)
g.fig.get_axes()[0].set_yscale('log')
plt.show()

# %%
df4 = df3.groupby(by=['popularity_quantile','playlist_lifetime_months']).monthly_streams.sum().reset_index()

# %%
df4.head()
# Out:
#   popularity_quantile  playlist_lifetime_months  monthly_streams
# 0       least_popular                        -9          466.000
# 1       least_popular                        -8          447.000
# 2       least_popular                        -7          426.000
# 3       least_popular                        -6          303.000
# 4       least_popular                        -5          385.000

# %%
g1 = sns.catplot(data=df4, x='popularity_quantile', y='monthly_streams', kind='box')
g1.fig.get_axes()[0].set_yscale('log')
plt.show()

# %%
track_data_sql = "SELECT * FROM `umg-comm-tech-dev.fixed_playlists.track_level_streams`"
track_data = gbq.read_gbq(query=track_data_sql, project_id='umg-comm-tech-dev', dialect='standard')
track_data.head()
# Out:
#               upc          isrc  year  month  monthly_streams
# 0  00602557462098  USUM71607007  2018      1          1537073
# 1  00602557462098  USUM71607007  2019      1          1149840
# 2  00602557814477  USUM71703088  2018      1           652934
# 3  00602557760347  USUM71709101  2018      1           629185
# 4  00602567108252  USUM71709292  2018      1           602605

# %%
len(track_data.upc.unique())
# Out:
# 282

# %%
track_data.groupby(by='upc').isrc.count().describe()
# Out:
# count   282.000
# mean    233.546
# std     173.340
# min      23.000
# 25%     100.000
# 50%     161.000
# 75%     352.000
# max     952.000
# Name: isrc, dtype: float64

# %%
summed_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams  \
# 0  00600406836304           Deezer  2018    09        0.026              6
# 1  00600406836304           Deezer  2018    10        0.019              4
# 2  00600406836304           Deezer  2018    11        0.005              1
# 3  00600406836304           Deezer  2018    12        0.010              2
# 4  00600406836304           Deezer  2019    01        0.005              1
#
#   release_date          title_theme year_month reports_date  \
# 0   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 1   2018-05-04  Blues For Breakfast     201810   2018-10-01
# 2   2018-05-04  Blues For Breakfast     201811   2018-11-01
# 3   2018-05-04  Blues For Breakfast     201812   2018-12-01
# 4   2018-05-04  Blues For Breakfast     201901   2019-01-01
#
#    playlist_lifetime_months  max_monthly_streams popularity_quantile
# 0                         4                 7715       least_popular
# 1                         5                 7715       least_popular
# 2                         6                 7715       least_popular
# 3                         7                 7715       least_popular
# 4                         8                 7715       least_popular

# %%
track_data['year']=[str(x) for x in track_data.year]
summed_data['year']=[str(x) for x in summed_data.year]
track_data['month'] = [str(x) if x > 9 else '0'+str(x) for x in track_data.month]

# %%
summed_data.year.dtype
# Out:
# dtype('O')

# %%
all_data = summed_data[summed_data.sub_account_name=='Spotify'].merge(track_data, how='left', on=['upc','year','month'])
all_data.head()
# Out:
#               upc sub_account_name  year month  euro_amount  total_streams  \
# 0  00600406836304          Spotify  2018    09       11.460           7715
# 1  00600406836304          Spotify  2018    09       11.460           7715
# 2  00600406836304          Spotify  2018    09       11.460           7715
# 3  00600406836304          Spotify  2018    09       11.460           7715
# 4  00600406836304          Spotify  2018    09       11.460           7715
#
#   release_date          title_theme year_month reports_date  \
# 0   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 1   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 2   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 3   2018-05-04  Blues For Breakfast     201809   2018-09-01
# 4   2018-05-04  Blues For Breakfast     201809   2018-09-01
#
#    playlist_lifetime_months  max_monthly_streams popularity_quantile  \
# 0                         4                 7715       least_popular
# 1                         4                 7715       least_popular
# 2                         4                 7715       least_popular
# 3                         4                 7715       least_popular
# 4                         4                 7715       least_popular
#
#            isrc  monthly_streams
# 0  USEM38600114         5561.000
# 1  USMC16048802          208.000
# 2  USMC16312115          198.000
# 3  USMC15646854          188.000
# 4  USMC15507777          184.000

# %%
all_data['streams_perc'] = all_data.monthly_streams/all_data.total_streams

# %%
all_data.streams_perc.describe()

# %%
lifetime_test = all_data[all_data.upc=='00602567171706']

# %%
lifetime_test['streams_perc'] = lifetime_test.monthly_streams/lifetime_test.total_streams
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lifetime_test[lifetime_test.streams_perc>0.9]
# Out:
#                   upc sub_account_name  year month  euro_amount  \
# 46829  00602567171706          Spotify  2017    12        1.717
# 46830  00602567171706          Spotify  2017    12        1.717
# 46831  00602567171706          Spotify  2017    12        1.717
# 46832  00602567171706          Spotify  2017    12        1.717
# 46833  00602567171706          Spotify  2017    12        1.717
# 46834  00602567171706          Spotify  2017    12        1.717
# 46835  00602567171706          Spotify  2017    12        1.717
# 46836  00602567171706          Spotify  2017    12        1.717
# 46837  00602567171706          Spotify  2017    12        1.717
# 46838  00602567171706          Spotify  2017    12        1.717
# 46839  00602567171706          Spotify  2017    12        1.717
# 46840  00602567171706          Spotify  2017    12        1.717
# 46841  00602567171706          Spotify  2017    12        1.717
# 46842  00602567171706          Spotify  2017    12        1.717
# 46843  00602567171706          Spotify  2017    12        1.717
# 46844  00602567171706          Spotify  2017    12        1.717
# 46845  00602567171706          Spotify  2017    12        1.717
# 46846  00602567171706          Spotify  2017    12        1.717
# 46847  00602567171706          Spotify  2017    12        1.717
# 46848  00602567171706          Spotify  2017    12        1.717
# 46849  00602567171706          Spotify  2017    12        1.717
#
#        total_streams release_date title_theme year_month reports_date  \
# 46829            127   2017-12-01   90's Rock     201712   2017-12-01
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.describe()
# Out:
#        quantile_num
# count       272.000
# mean          1.022
# std           0.703
# min           0.000
# 25%           1.000
# 50%           1.000
# 75%           2.000
# max           2.000

# %%
stemmer = PorterStemmer()
words = stopwords.words("english")

df['title_theme'] = [str(x) for x in df.title_theme]

df['cleaned'] = df['title_theme'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z0-9]", " ", x).split() if i not in words]).lower())

# %%
df.head()
# Out:
#            title_theme        quantile  quantile_num             cleaned
# 0  Blues For Breakfast   least_popular             0  blue for breakfast
# 1        Midnight Jazz   least_popular             0       midnight jazz
# 2     Chopin For Study   least_popular             0    chopin for studi
# 3         Father's Day  middle_popular             1          father day
# 4       Country Queens   least_popular             0       countri queen

# %%
vectorizer = TfidfVectorizer(min_df= 3, stop_words="english", sublinear_tf=True, norm='l2', ngram_range=(1, 3))
final_features = vectorizer.fit_transform(df['cleaned']).toarray()
final_features.shape
# Out:
# (272, 62)

# %%
X = final_features
y = df['quantile_num']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, stratify=y)

# %%
gs_params_rfc = {
    'n_estimators' : [5,10,15],
    'max_depth' : [5,10,None],
    'class_weight': ['balanced'],
    'verbose' : [1]
}

model = RandomForestClassifier()

# %%
gs = GridSearchCV(model, param_grid=gs_params_rfc, verbose = 1, n_jobs=2)
gs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  24 out of  27 | elapsed:    1.2s remaining:    0.2s
# [Parallel(n_jobs=2)]: Done  27 out of  27 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=2,
#        param_grid={'n_estimators': [5, 10, 15], 'max_depth': [5, 10, None], 'class_weight': ['balanced'], 'verbose': [1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
predict = gs.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished

# %%
classification_metrics(gs.best_estimator_, X_test, y_test, predict)
# Out:
# Accuracy score:
# 0.4878048780487805
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        10
#            1       0.56      0.43      0.49        21
#            2       0.40      0.60      0.48        10
#
#    micro avg       0.49      0.49      0.49        41
#    macro avg       0.49      0.51      0.49        41
# weighted avg       0.51      0.49      0.49        41

# %%
coefs = list(zip(importances, cols))

# %%
cols = vectorizer.get_feature_names()

# %%
pd.DataFrame(coefs, columns=['coef','feature']).sort_values(by='coef', ascending=False)
# Out:
#     coef        feature
# 31 0.091           jazz
# 54 0.083          studi
# 13 0.081       christma
# 43 0.073            pop
# 45 0.066            rap
# 40 0.064            new
# 15 0.057        classic
# 55 0.056         summer
# 25 0.052            hit
# 33 0.043            let
# 10 0.041           blue
# 17 0.030           danc
# 23 0.029        hip hop
# 59 0.029            vol
# 27 0.024            hop
# 36 0.021           love
# 53 0.019           soul
# 60 0.019          women
# 18 0.015            day
# 22 0.015            hip
# 5  0.013             90
# 39 0.012          music
# 47 0.010     relax jazz
# 29 0.010   hop hit list
# 4  0.009             80
# 50 0.009           rock
# 56 0.007    summer danc
# 16 0.006        countri
# 28 0.006        hop hit
# 46 0.006          relax
# ..   ...            ...
# 52 0.000           song
# 51 0.000         school
# 48 0.000           road
# 57 0.000           trip
# 44 0.000        pop hit
# 42 0.000          parti
# 41 0.000           note
# 49 0.000      road trip
# 0  0.000             00
# 38 0.000         mixtap
# 14 0.000  christma song
# 2  0.000           2018
# 3  0.000             70
# 6  0.000         altern
# 7  0.000         anthem
# 8  0.000           best
# 9  0.000      best 2017
# 11 0.000      blue note
# 12 0.000          chill
# 19 0.000         dinner
# 37 0.000          metal
# 20 0.000   dinner parti
# 21 0.000         guitar
# 26 0.000       hit list
# 30 0.000           indi
# 1  0.000           2017
# 32 0.000          latin
# 34 0.000           list
# 35 0.000          loung
# 61 0.000        workout
#
# [62 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, Ridge, LogisticRegressionCV

# %%
logreg_parameters = {
    'penalty':['l1','l2'],
    'C':np.logspace(-5,1,50),
    'solver':['liblinear']
}
logreg2=LogisticRegression()
gs_lr=GridSearchCV(logreg2,logreg_parameters,cv=5,verbose=1)
gs_lr.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
# ...
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.4s finished
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([1.00000e-05, 1.32571e-05, 1.75751e-05, 2.32995e-05, 3.08884e-05,
#        4.09492e-05, 5.42868e-05, 7.19686e-05, 9.54095e-05, 1.26486e-04,
#        1.67683e-04, 2.22300e-04, 2.94705e-04, 3.90694e-04, 5.17947e-04,
#        6.86649e-04, 9.10298e-04, 1.20679e-...,
#        3.23746e+00, 4.29193e+00, 5.68987e+00, 7.54312e+00, 1.00000e+01]), 'solver': ['liblinear']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
predict = gs_lr.predict(X_test)\

# %%
classification_metrics(gs_lr, X_test, y_test, predict)
# Out:
# Accuracy score:
# 0.43902439024390244
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40        10
#            1       0.46      0.62      0.53        21
#            2       0.33      0.10      0.15        10
#
#    micro avg       0.44      0.44      0.44        41
#    macro avg       0.40      0.37      0.36        41
# weighted avg       0.42      0.44      0.41        41

# %%
coefs = list(zip(gs_lr.best_estimator_.coef_[1], cols))

# %%
pd.DataFrame(coefs, columns=['coef','feature']).sort_values(by='coef', ascending=False)
# Out:
#      coef       feature
# 6   2.246        altern
# 11  1.889     blue note
# 55  1.485        summer
# 4   1.396            80
# 18  1.341           day
# 3   1.294            70
# 0   0.947            00
# 2   0.898          2018
# 8   0.877          best
# 12  0.815         chill
# 15  0.709       classic
# 16  0.687       countri
# 41  0.656          note
# 36  0.651          love
# 54  0.640         studi
# 37  0.621         metal
# 50  0.608          rock
# 42  0.603         parti
# 13  0.586      christma
# 58  0.378          vibe
# 61  0.271       workout
# 7   0.198        anthem
# 52  0.184          song
# 23  0.138       hip hop
# 17  0.000          danc
# 20  0.000  dinner parti
# 51  0.000        school
# 46  0.000         relax
# 45  0.000           rap
# 44  0.000       pop hit
# ..    ...           ...
# 22  0.000           hip
# 40  0.000           new
# 19  0.000        dinner
# 56  0.000   summer danc
# 59  0.000           vol
# 29  0.000  hop hit list
# 24  0.000   hip hop hit
# 60  0.000         women
# 26  0.000      hit list
# 34  0.000          list
# 28  0.000       hop hit
# 27  0.000           hop
# 33  0.000           let
# 49 -0.004     road trip
# 48 -0.040          road
# 57 -0.089          trip
# 1  -0.098          2017
# 47 -0.380    relax jazz
# 10 -0.501          blue
# 30 -0.590          indi
# 39 -0.697         music
# 5  -0.799            90
# 32 -1.099         latin
# 38 -1.104        mixtap
# 9  -1.376     best 2017
# 31 -1.412          jazz
# 21 -1.876        guitar
# 25 -1.939           hit
# 35 -2.185         loung
# 53 -2.885          soul
#
# [62 rows x 2 columns]

# %%
df[df.cleaned.str.contains('christ')]
# Out:
#                           title_theme        quantile  quantile_num  \
# 65                 Christmas Top Hits    most_popular             2
# 67                  Christmas Country  middle_popular             1
# 68                      Christmas Pop  middle_popular             1
# 69                     Christmas Rock  middle_popular             1
# 71                Christmas With Bing    most_popular             2
# 72            Christmas Hip Hop N R&B   least_popular             0
# 77   Frank Sinatra Christmas Classics  middle_popular             1
# 90        Alternative Christmas Songs  middle_popular             1
# 91                     Christmas Soul  middle_popular             1
# 92                 Christmas Classics  middle_popular             1
# 93      Digging Deeper Into Christmas  middle_popular             1
# 95            Ultimate Christmas Jazz  middle_popular             1
# 98        Classical Christmas Carols   middle_popular             1
# 100           Classic Christmas Songs    most_popular             2
# 101          Relaxing Christmas Songs  middle_popular             1
# 102            Country Christmas Hits  middle_popular             1
# 103             Blues Christmas Songs  middle_popular             1
# 104              Gotta Love Christmas  middle_popular             1
# 105    Have Yourself A Jazz Christmas  middle_popular             1
# 107          Christmas Cocktail Party  middle_popular             1
# 108               Pop Christmas Songs    most_popular             2
# 111           Music for Christmas Eve   least_popular             0
# 112           Music for Christmas Day   least_popular             0
# 125            Classic Jazz Christmas  middle_popular             1
# 126                         Christmas    most_popular             2
# 127                   Christmas Blues  middle_popular             1
# 128                    Christmas Jazz  middle_popular             1
# 170          Christmas Hip Hop 'N R&B  middle_popular             1
# 177                    Christmas Rock    most_popular             2
# 204                     Christmas Pop    most_popular             2
# 213             A Hollywood Christmas   least_popular             0
#
#                             cleaned
# 65                 christma top hit
# 67                 christma countri
# 68                     christma pop
# 69                    christma rock
# 71               christma with bing
# 72           christma hip hop n r b
# 77   frank sinatra christma classic
# 90             altern christma song
# 91                    christma soul
# 92                 christma classic
# 93         dig deeper into christma
# 95              ultim christma jazz
# 98           classic christma carol
# 100           classic christma song
# 101             relax christma song
# 102            countri christma hit
# 103              blue christma song
# 104             gotta love christma
# 105   have yourself a jazz christma
# 107         christma cocktail parti
# 108               pop christma song
# 111              music christma eve
# 112              music christma day
# 125           classic jazz christma
# 126                        christma
# 127                   christma blue
# 128                   christma jazz
# 170          christma hip hop n r b
# 177                   christma rock
# 204                    christma pop
# 213            a hollywood christma

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = pd.DataFrame(coefs, columns=['coef','feature']).sort_values(by='coef', ascending=False)
text_pos = text[text.coef>0].reset_index(drop=True)
text_neg = text[text.coef<0].reset_index(drop=True)

# %%
text_pos_input = ' '.join(text_pos.feature)
text_neg_input = ' '.join(text_neg.feature)

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text_pos_input)

# %%
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud2 = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text_neg_input)
plt.figure()
plt.imshow(wordcloud2, interpolation="bilinear")
plt.axis("off")
plt.show()
