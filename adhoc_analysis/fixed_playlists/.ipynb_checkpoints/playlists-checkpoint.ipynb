# %%
import pandas as pd
from pandas.io import gbq

# %%
table_df = gbq.read_gbq("SELECT * FROM `umg-comm-tech-dev.fixed_playlists_data.playlists_list`",
                       project_id = "umg-comm-tech-dev", dialect = 'standard')
table_df.head()
# Out:
#   artists genre playlist_owner release_date               release_title  \
# 0    None  None           None   2016-11-23                   Christmas
# 1    None  None           None   2016-12-09             Christmas Blues
# 2    None  None           None   2016-12-09              Christmas Jazz
# 3    None  None           None   2017-01-27              Crowd Pleasers
# 4    None  None           None   2017-02-03  Let Me Love You Old School
#
#   repertoire_pools status streaming_services take_down_date territory  \
# 0             None   None               None            NaT      None
# 1             None   None               None            NaT      None
# 2             None   None               None            NaT      None
# 3             None   None               None            NaT      None
# 4             None   None               None            NaT      None
#
#               upc
# 0  00602557103601
# 1  00602557342697
# 2  00602557342703
# 3  00602557414387
# 4  00602557437638

# %%
table_df.describe(include='all')
# Out:
#                 artists genre   playlist_owner         release_date  \
# count               467   467              467                  645
# unique                5    31               29                  128
# top     Various artists  Jazz  William Freeman  2019-04-19 00:00:00
# freq                462   175              122                   36
# first               NaN   NaN              NaN  2016-11-23 00:00:00
# last                NaN   NaN              NaN  2019-05-17 00:00:00
#
#           release_title repertoire_pools     status  \
# count               645              467        467
# unique              571               13          7
# top     Bossa Nova Hits        Catalogue  DELIVERED
# freq                  5              215        425
# first               NaN              NaN        NaN
# last                NaN              NaN        NaN
#
#                                        streaming_services  \
# count                                                 407
# unique                                                  3
# top     Spotify;Deezer;Napster;7digital;Amazon;Tidal;Y...
# freq                                                  380
# first                                                 NaN
# last                                                  NaN
#
#              take_down_date  \
# count                    57
# unique                   25
# top     2018-10-09 00:00:00
# freq                     13
# first   2018-02-20 00:00:00
# last    2035-07-02 00:00:00
#
#                                                 territory             upc
# count                                                 407             645
# unique                                                  9             645
# top     AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;EC;ES;FI;F...  00600406836885
# freq                                                  226               1
# first                                                 NaN             NaN
# last                                                  NaN             NaN

# %%
dtype_dict = {
    'upc':str
}

col_names = ['upc','release_title','artists', 'genre', 'status', 'release_date', 'take_down_date', 'playlist_owner', 
       'repertoire_pools', 'streaming_services', 'territory']

# %%
new_data = pd.read_csv('/Users/daria/Downloads/compilations-2019-05-03.csv', index_col=None, dtype=dtype_dict,
                      header=0, names=col_names)
new_data.head()
# Out:
#               upc              release_title          artists  genre  \
# 0             NaN  Jazz Standards: The 1920s  Various artists   Jazz
# 1  00600406836304        Blues For Breakfast  Various artists  Blues
# 2             NaN                  Punk Hits  Various artists   Punk
# 3  00600406836311              Midnight Jazz  Various artists   Jazz
# 4  00600406836366                Smooth Jazz  Various artists   Jazz
#
#       status release_date take_down_date  playlist_owner  repertoire_pools  \
# 0      DRAFT   2018-05-11            NaN  Kayla Schmandt         Catalogue
# 1  DELIVERED   2018-05-04            NaN   James Burnett         Catalogue
# 2     CLOSED   2018-05-07            NaN  Kayla Schmandt         Catalogue
# 3  DELIVERED   2018-05-11            NaN  Kayla Schmandt  Classical / Jazz
# 4  DELIVERED   2018-06-08     2018-10-10  Kayla Schmandt  Classical / Jazz
#
#                        streaming_services  \
# 0  Spotify;Deezer;Napster;7digital;Amazon
# 1  Spotify;Deezer;Napster;7digital;Amazon
# 2  Spotify;Deezer;Napster;7digital;Amazon
# 3  Spotify;Deezer;Napster;7digital;Amazon
# 4  Spotify;Deezer;Napster;7digital;Amazon
#
#                                            territory
# 0  AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;DO;EC;ES;F...
# 1  AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;DO;EC;ES;F...
# 2  AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;DO;EC;ES;F...
# 3  AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;DO;EC;ES;F...
# 4  AR;AT;AU;BO;BR;CA;CH;CL;CO;CR;DE;DK;DO;EC;ES;F...

# %%
truly_new = new_data[(new_data.upc.isnull()==False)&(new_data.upc.isin(table_df.upc.unique())==False)]

truly_new['release_date'] = pd.to_datetime(truly_new.release_date)
truly_new['take_down_date'] = pd.to_datetime(truly_new.take_down_date)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
all_data = pd.concat([table_df,truly_new], ignore_index=True, sort=True)
all_data.upc.describe()
# Out:
# count                645
# unique               645
# top       00600406837097
# freq                   1
# Name: upc, dtype: object

# %%
all_data.to_gbq(destination_table="fixed_playlists_data.playlists_list",
                       project_id = "umg-comm-tech-dev", if_exists = 'replace')
# Out:
# 1it [00:05,  5.40s/it]

# %%
len(truly_new.upc.unique())
# Out:
# 12

# %%
all_data.shape
# Out:
# (597, 11)
