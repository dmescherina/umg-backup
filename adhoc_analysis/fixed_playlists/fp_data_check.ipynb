# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/daria/Downloads/results-20181204-100235.csv')
data.head()
# Out:
#   sub_account_name transaction_source transaction_date  year  month  \
# 0          YouTube            Finance       2018-06-15  2018      6
# 1          YouTube            Finance       2018-06-15  2018      6
# 2          YouTube            Finance       2018-06-15  2018      6
# 3          YouTube            Finance       2018-06-15  2018      6
# 4          YouTube            Finance       2018-06-15  2018      6
#
#    euro_amount           upc  total_streams
# 0     0.000000  602557462098             40
# 1     0.028899  602557462098            203
# 2     0.095032  602557462098             31
# 3     0.015834  602557462098             58
# 4     0.007877  602557462098             24

# %%
sns.scatterplot(data=data[data.upc==upcs[0]], x='euro_amount', y='total_streams')

# %%
sns.scatterplot(data=data[data.upc==upcs[1]], x='euro_amount', y='total_streams')

# %%
sns.scatterplot(data=data[data.upc==upcs[2]], x='euro_amount', y='total_streams')

# %%
sns.scatterplot(data=data[data.upc==upcs[3]], x='euro_amount', y='total_streams')

# %%
sns.scatterplot(data=data[data.upc==upcs[4]], x='euro_amount', y='total_streams')

# %%
data['euros_per_1000_streams'] = [(x/y)*1000 for (x,y) in zip(data.euro_amount,data.total_streams)]

# %%
upcs = data.upc.unique()

# %%
for upc in upcs:
    sns.distplot(data[data.upc==upc].euros_per_1000_streams)

# %%
sns.catplot(y="euros_per_1000_streams", x="upc", kind="boxen",
            data=data)

# %%
data[data.euros_per_1000_streams>5].transaction_date.unique()
# Out:
# array(['2018-06-15', '2018-07-15', '2018-08-15', '2018-09-15',
#        '2018-10-15', '2018-05-15', '2017-09-15', '2017-10-15',
#        '2017-11-15', '2017-12-15', '2018-01-15', '2018-02-15',
#        '2018-03-15', '2018-04-15', '2017-08-15'], dtype=object)
