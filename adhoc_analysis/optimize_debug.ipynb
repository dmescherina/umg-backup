# %%
import pandas as pd

# %%
umg = pd.read_csv("/Users/daria/Downloads/apollo_export_20190131", delimiter='\t', header=None)
umg.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-38-043ca3265bb8> in <module>
# ----> 1 umg = pd.read_csv("/Users/daria/Downloads/apollo_export_20190131", delimiter='\t', header=None)
#       2 umg.head()
#
# ...

# %%
non_umg = pd.read_csv("/Users/daria/Downloads/apollo_export_non_umg_20190131", delimiter='\t', header=None)
non_umg.head()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                         0                                                 1   \
# 0  2019-01-31 00:00:00 UTC  spotify:user:3fm:playlist:1yzak2pFIMsjWQRD38Hstf
# 1  2019-01-31 00:00:00 UTC  spotify:user:3fm:playlist:1yzak2pFIMsjWQRD38Hstf
# 2  2019-01-31 00:00:00 UTC  spotify:user:3fm:playlist:1yzak2pFIMsjWQRD38Hstf
# 3  2019-01-31 00:00:00 UTC  spotify:user:3fm:playlist:1yzak2pFIMsjWQRD38Hstf
# 4  2019-01-31 00:00:00 UTC  spotify:user:3fm:playlist:1yzak2pFIMsjWQRD38Hstf
#
#    2             3                                     4   \
# 0  37  GBENL1802328  spotify:track:0cbKVnJ49Jvb4d6A09M5vN
# 1  50  QMRSZ1800686  spotify:track:0cSNN4fgW1RFDQV58eVRKK
# 2   6  USSM11900111  spotify:track:5kXDF4OmM5COyeo6z97nEk
# ...

# %%
umg_isrc = list(umg.iloc[:,3].unique())

# %%
non_umg_isrc = list(non_umg.iloc[:,3].unique())

# %%
both = list(set(umg_isrc) & set(non_umg_isrc))

# %%
len(both)
# Out:
# 2473

# %%
umg[(umg[3].isin(both))&(umg[35]=='digster.co.uk')][32].describe()
# Out:
# count     166
# unique      1
# top       UMG
# freq      166
# Name: 32, dtype: object

# %%
conc = pd.concat([umg, non_umg], ignore_index=True)

# %%
digster_uk_by_isrc = conc[conc[35]=='digster.co.uk'].groupby(by=3)

# %%
digster_uk_by_isrc[32].nunique().sort_values(ascending=False)
# Out:
# 3
# INUM71900010    2
# GBUM71900216    2
# GBUM71901065    2
# USATO1800422    2
# GBUM71807393    1
# GBUM71807200    1
# GBUM71807267    1
# GBUM71807337    1
# GBUM71807386    1
# GBUM71807392    1
# GBUM71807403    1
# GBUM71807114    1
# GBUM71807425    1
# GBUM71807426    1
# GBUM71807541    1
# GBUM71807542    1
# GBUM71807544    1
# GBUM71807175    1
# GBUM71807040    1
# GBUM71807100    1
# GBUM71806413    1
# GBUM71807039    1
# GBUM71807002    1
# GBUM71806962    1
# GBUM71806918    1
# GBUM71806861    1
# GBUM71806768    1
# GBUM71806743    1
# GBUM71806547    1
# GBUM71806535    1
#                ..
# USKFE0700003    1
# USLF29900479    1
# USQ4E1602586    1
# USQ4E1602392    1
# USQ4E1300686    1
# USPR39401582    1
# USPR38619998    1
# USPR37930021    1
# USPR37509157    1
# USPR37030030    1
# USPR36702767    1
# USNLR1800087    1
# USNLR0700062    1
# USNA18715142    1
# USMR19900016    1
# USMR19887508    1
# USMR19786993    1
# USMO18390005    1
# ...

# %%
digster_doubles = ['INUM71900010','GBUM71900216','GBUM71901065','USATO1800422']

# %%
conc[(conc[35]=='digster.co.uk')&(conc[3].isin(digster_doubles))].sort_values(by=[1,3])
# Out:
#                              0   \
# 242344  2019-04-09 00:00:00 UTC
# 242348  2019-04-09 00:00:00 UTC
# 242350  2019-04-09 00:00:00 UTC
# 242339  2019-04-09 00:00:00 UTC
# 142153               2019-04-09
# 142122               2019-04-09
# 142174               2019-04-09
# 142216               2019-04-09
# 204250               2019-04-09
#
#                                                        1   2             3   \
# 242344  spotify:user:digster.co.uk:playlist:4OxX9SacaI...  46  GBUM71900216
# 242348  spotify:user:digster.co.uk:playlist:4OxX9SacaI...  39  GBUM71901065
# 242350  spotify:user:digster.co.uk:playlist:4OxX9SacaI...  58  INUM71900010
# 242339  spotify:user:digster.co.uk:playlist:4OxX9SacaI...  56  USATO1800422
# 142153  spotify:user:digster.co.uk:playlist:6Ek1eTWRVX...  11  GBUM71901065
# 142122  spotify:user:digster.co.uk:playlist:6Ek1eTWRVX...  22  INUM71900010
# 142174  spotify:user:digster.co.uk:playlist:6N2jNKds70...   8  GBUM71900216
# ...
