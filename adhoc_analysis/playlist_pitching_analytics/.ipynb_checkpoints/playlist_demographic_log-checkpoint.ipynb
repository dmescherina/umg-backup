# %%
import pandas as pd
from pandas.io import gbq

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# #### Get Spotify playlists of interest

# %%
get_throwback_in_uk_browse = """
SELECT
  category_name,
  playlist_id,
  playlist_name
FROM
  `umg-alpha.spotify.spotify_playlist_browse`
WHERE
  owner_id = "spotify"
  AND category_id = "decades"
  AND territory = "GB"
GROUP BY
  1,
  2,
  3
"""

# %% [markdown]
# #### Get the demographics that are listening to these Spotify playlists
#
# Rank each demographic audience by the number of streams they do from each playlist

# %%
get_spotify_demographics = """
WITH
  playlists AS (
  SELECT
    category_name,
    playlist_id,
    playlist_name
  FROM
    `umg-comm-tech-dev.playlist_pitching_analytics.top_browse_uk_playlists`
  GROUP BY
    1,
    2,
    3)
SELECT
  category_name,
  playlist_id,
  playlist_name,
  user_country_name,
  user_gender,
  user_age,
  s.user_age_group,
  COUNT(*) AS streams
FROM
  playlists p
LEFT JOIN
  `umg-edw.spotify.streams` s
ON
  p.playlist_id=REGEXP_EXTRACT(s.source_uri,r'playlist:(.*)')
WHERE
  s.stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 21 DAY)
  AND s.stream_date < CURRENT_DATE()
  AND s.user_country_code = "GB"
  AND s.user_gender != ''
  AND s.user_age IS NOT NULL
GROUP BY
  category_name,
  playlist_id,
  playlist_name,
  user_country_name,
  user_gender,
  user_age,
  s.user_age_group
"""

# %%
spotify_demographic_groups = """
SELECT
  playlist_id,
  playlist_name,
  user_gender,
  user_age_group,
  SUM(streams) AS streams,
  SUM(listeners) AS listeners,
  RANK() OVER(PARTITION BY playlist_name ORDER BY SUM(streams) DESC) AS rank_streams
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.demographics_spotify`
WHERE
  user_gender != ''
  AND user_age IS NOT NULL
GROUP BY
  playlist_id,
  playlist_name,
  user_gender,
  user_age_group
"""

# %%
sp_demographics = gbq.read_gbq(spotify_demographic_groups, project_id='umg-comm-tech-dev', dialect='standard')

# %%
sp_demographics.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          18-24
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          18-24
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          35-44
#
#    streams  listeners  rank_streams
# 0   640957      54211             1
# 1   457860      41326             2
# 2   279854      43351             3
# 3   184072      25379             4
# 4   183278      14380             5

# %%
sp_demographics=sp_demographics[sp_demographics.user_age_group!="Unknown"]

# %% [markdown]
# #### Checking the audiences for these playlists and their relative distribution

# %%
by_gender_age = sp_demographics.groupby(by=['user_gender','user_age_group'])

# %%
df_dem_sp = pd.DataFrame(by_gender_age.streams.sum())
df_dem_sp['listeners'] = by_gender_age.listeners.sum()
df_dem_sp['playlist_listens']=by_gender_age.playlist_id.nunique()

# %%
df_dem_sp = df_dem_sp.reset_index()
df_dem_sp.head()
# Out:
#   user_gender user_age_group  streams  listeners  playlist_listens
# 0      female           0-12     1514        151                27
# 1      female          13-17   542980      78607                64
# 2      female          18-24  4859921     599032                68
# 3      female          25-34  6379359     671109                67
# 4      female          35-44  2622252     255977                68

# %%
fig = plt.figure(figsize=(16,8))

cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sns.scatterplot(data=df_dem_sp, x='user_age_group', y='streams', size='listeners', sizes=(50,250),
                style='user_gender', hue='listeners', legend="full",
                palette="Set2")

plt.show()

# %% [markdown]
# Demographics is nostly as expected. Most numerous audiences are both men and women between 25-34, then 18-24 (notably girls more than boys), then 35-44s, 45-54th, etc. Interestingly 45-54 year olds have the same amount opf listeners as 55-64 year olds, but the former generate significantly more streams.

# %% [markdown]
# #### Get the ranking of ALL artists on Apple for each of our demographic groups...

# %%
apple_artist_ranks_global = """
SELECT
  apple_artist_id,
  artist_name,
  user_gender,
  user_age_group,
  SUM(stream_count) AS streams,
  SUM(listener_count) AS listeners,
  RANK() OVER(PARTITION BY user_gender,user_age_group ORDER BY SUM(stream_count) DESC) AS artist_rank
FROM
  `umg-edw.apple_music.daily_artist_demographics`
WHERE stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 7 DAY)
  AND stream_date < CURRENT_DATE()
  AND user_country_code ="GB"
  GROUP BY
  apple_artist_id,
  artist_name,
  user_gender,
  user_age_group
"""

# %% [markdown]
# #### ...and then select our top 80 catalogue artists, their rankings for each demographic and their tracks

# %%
apple_artist_content_demographic = """
SELECT
  artist_id,
  isrc,
  title,
  d.artist_name,
  d.user_gender,
  d.user_age_group,
  r.artist_rank,
  SUM(listener_count) AS listener_count,
  SUM(stream_count) AS stream_count
FROM
  `umg-edw.apple_music.daily_content_demographics` d
LEFT JOIN
  `umg-comm-tech-dev.playlist_pitching_analytics.artist_global_ranking` r
ON
  d.artist_id = r.apple_artist_id
  AND d.user_gender = r.user_gender
  AND d.user_age_group = r.user_age_group
WHERE
  stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 21 DAY)
  AND stream_date < CURRENT_DATE()
  AND artist_id IN (
  SELECT
    artist_id_apple
  FROM
    `umg-comm-tech-dev.hundred_artist.joined_artists_track_data`
  GROUP BY
    artist_id_apple)
  AND user_country_code = "GB"
GROUP BY
  artist_id,
  isrc,
  title,
  artist_name,
  user_gender,
  user_age_group,
  r.artist_rank 
"""

# %%
global_ranking = """
SELECT
  *,
IF
  (apple_artist_id IN (
    SELECT
      artist_id_apple
    FROM
      `umg-comm-tech-dev.hundred_artist.joined_artists_track_data`
    GROUP BY
      artist_id_apple),
    1,
    0) AS in_analysis
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.artist_global_ranking`
"""

apple_demographic = gbq.read_gbq(global_ranking, project_id='umg-comm-tech-dev', dialect='standard')
apple_demographic.head()
# Out:
#          apple_artist_id           artist_name   user_gender user_age_group  \
# 0  1276656483,1236267297       Lil Baby, Gunna  Data Unknown          18-24
# 1    980795202,420203509  Marshmello, Bastille  Data Unknown          18-24
# 2                2770824                  DEAN  Data Unknown          18-24
# 3              622429974         X Ambassadors  Data Unknown          18-24
# 4              378430797        Julia Michaels  Data Unknown          18-24
#
#    streams  listeners  artist_rank  in_analysis
# 0     1001        481           49            0
# 1      342        246          115            0
# 2      127         53          184            0
# 3      127         21          184            0
# 4      120         78          188            0

# %%
df_apple = apple_demographic[(apple_demographic.user_gender!='Data Unknown')&(apple_demographic.user_age_group!='Data Unknown')]

# %% [markdown]
# #### Let's check how popular are our top80 catalogue artists in each of the demographic

# %%
fig = plt.figure(figsize=(16,8))

sns.boxplot(data = df_apple[df_apple.in_analysis==1], x='artist_rank', y='user_age_group', hue='user_gender',
           palette="Set2")

plt.show()

# %% [markdown]
# It's fair to say that our artists are quite popular equally in all the demographics. 75% of those artists are ranked under 250 in all demographics. The least liked artist by 45-54s that has the ranking of lower than 5000s in their group is Eason Chan :)

# %% [markdown]
# ![](8ed.jpg)

# %%
df_apple[(df_apple.in_analysis==1)&(df_apple.artist_rank>5000)]
# Out:
#       apple_artist_id artist_name user_gender user_age_group  streams  \
# 11885       137938148         陳奕迅        Male          45-54        5
#
#        listeners  artist_rank  in_analysis
# 11885          5         5198            1

# %% [markdown]
# Below is the distribution of ALL artists on Apple ranking within each demographic. Safe to say our top 80 are doing better than average

# %%
fig = plt.figure(figsize=(16,8))

sns.boxplot(data = df_apple, x='artist_rank', y='user_age_group', hue='user_gender',
           palette="Set3")

plt.show()

# %% [markdown]
# #### Getting all our artists and their songs where their respective rank in each demographic group is no lower than 250

# %%
our_ranking = """
SELECT
  *
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.apple_content_demographic`
WHERE
  artist_rank <= 250
  AND user_gender != 'Data Unknown'
  AND user_age_group != 'Data Unknown'
"""

apple_demographic_tracks = gbq.read_gbq(our_ranking, project_id='umg-comm-tech-dev', dialect='standard')
apple_demographic_tracks.head()
# Out:
#   artist_id          isrc                               title artist_name  \
# 0     54657  GBA098000020                      Little Jeannie  Elton John
# 1     54657  GBA098100030                   Just Like Belgium  Elton John
# 2     54657  GBA098200070       Empty Garden (Hey Hey Johnny)  Elton John
# 3     54657  GBAKW7501037                      Pinball Wizard  Elton John
# 4     54657  GBALX7600002  Sorry Seems To Be the Hardest Word  Elton John
#
#   user_gender user_age_group  artist_rank  listener_count  stream_count
# 0        Male          55-64            1              15            17
# 1        Male          55-64            1             144           169
# 2        Male          55-64            1               5             5
# 3        Male          55-64            1              68            89
# 4        Male          55-64            1             850          1026

# %%
sp_demographics.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          18-24
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          18-24
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday        male          35-44
#
#    streams  listeners  rank_streams
# 0   640957      54211             1
# 1   457860      41326             2
# 2   279854      43351             3
# 3   184072      25379             4
# 4   183278      14380             5

# %%
sp_demographics.user_age_group.unique()
# Out:
# array(['25-34', '18-24', '35-44', '45-54', '55-64', '13-17', '65+',
#        '0-12'], dtype=object)

# %%
sp_demographics.user_gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
apple_demographic_tracks.user_age_group.unique()
# Out:
# array(['55-64', '65+', '45-54', '35-44', '18-24', '25-34'], dtype=object)

# %%
apple_demographic_tracks['user_gender'] = [str(x).lower() for x in apple_demographic_tracks.user_gender]

# %%
apple_demographic_tracks.user_gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# #### Getting together Spotify playlist demographics with apple demographics and our top80 catalogue artists' rep

# %%
df_all = pd.merge(sp_demographics,apple_demographic_tracks, on = ['user_gender', 'user_age_group'])
df_all.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc            title  \
# 0   640957      54211             1  298496035  CH3131340083      You Make Me
# 1   640957      54211             1  298496035  CH3131340084      Hey Brother
# 2   640957      54211             1  298496035  CH3131340085  Addicted To You
# 3   640957      54211             1  298496035  CH3131340086         Dear Boy
# 4   640957      54211             1  298496035  CH3131340087        Liar Liar
#
#   artist_name  artist_rank  listener_count  stream_count
# 0      Avicii            7            2417          2972
# 1      Avicii            7            6266          8170
# 2      Avicii            7            4278          5643
# 3      Avicii            7             371           491
# 4      Avicii            7             318           411

# %%
df_all.to_gbq(destination_table='playlist_pitching_analytics.apple_suggestions', project_id='umg-comm-tech-dev',
             if_exists='replace')
# Out:
# 1it [00:36, 36.58s/it]

# %% [markdown]
# #### Now checking which of these tracks and artists are already in those respective Spotify playlists

# %%
check_track_listings = """
SELECT
  playlist_id,
  track_artist,
  track_title,
  isrc
FROM
  `umg-edw.spotify.playlist_track_history`
WHERE
  playlist_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 21 DAY)
  AND playlist_date < CURRENT_DATE()
  AND playlist_id IN (
  SELECT
    playlist_id
  FROM
    `umg-comm-tech-dev.playlist_pitching_analytics.top_browse_uk_playlists`
  GROUP BY
    1)
GROUP BY
  playlist_id,
  track_artist,
  track_title,
  isrc
"""

# %%
track_listings = gbq.read_gbq(check_track_listings, project_id='umg-comm-tech-dev', dialect='standard')
track_listings['isrc_in_playlist'] = 1
track_listings.head()
# Out:
#               playlist_id   track_artist            track_title          isrc  \
# 0  37i9dQZF1DX13AH4vV1R8I  Leslie Cheung                   風再起時  HKG070100116
# 1  37i9dQZF1DX13AH4vV1R8I  Leslie Cheung  奔向未來日子(電影"英雄本色續集"主題曲)  HKG070100113
# 2  37i9dQZF1DX13AH4vV1R8I  Leslie Cheung                   春夏秋冬  HKB829900005
# 3  37i9dQZF1DX13AH4vV1R8I  Leslie Cheung                   共同渡過  HKG070100115
# 4  37i9dQZF1DX13AH4vV1R8I  Leslie Cheung                     Wo  HKB820000012
#
#    isrc_in_playlist
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
df_all_tracks = pd.merge(df_all, track_listings, on=['playlist_id','isrc'], how='left')
df_all_tracks['isrc_in_playlist'] = df_all_tracks.isrc_in_playlist.fillna(int(0))
df_all_tracks.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc            title  \
# 0   640957      54211             1  298496035  CH3131340083      You Make Me
# 1   640957      54211             1  298496035  CH3131340084      Hey Brother
# 2   640957      54211             1  298496035  CH3131340085  Addicted To You
# 3   640957      54211             1  298496035  CH3131340086         Dear Boy
# 4   640957      54211             1  298496035  CH3131340087        Liar Liar
#
#   artist_name  artist_rank  listener_count  stream_count track_artist  \
# 0      Avicii            7            2417          2972          NaN
# 1      Avicii            7            6266          8170          NaN
# 2      Avicii            7            4278          5643          NaN
# 3      Avicii            7             371           491          NaN
# 4      Avicii            7             318           411          NaN
#
#   track_title  isrc_in_playlist
# 0         NaN             0.000
# 1         NaN             0.000
# 2         NaN             0.000
# 3         NaN             0.000
# 4         NaN             0.000

# %%
by_pl_art = df_all_tracks.groupby(by=['playlist_id','track_artist']).isrc_in_playlist.max()
df_pl_art = pd.DataFrame(by_pl_art).reset_index()
df_pl_art.columns = ['playlist_id','track_artist','artist_in_playlist']
df_pl_art.head()
# Out:
#               playlist_id                  track_artist  artist_in_playlist
# 0  00K2xasnm9pDQk53SzNCht                          ABBA               1.000
# 1  00K2xasnm9pDQk53SzNCht                      Bee Gees               1.000
# 2  00K2xasnm9pDQk53SzNCht      Bob Marley & The Wailers               1.000
# 3  00K2xasnm9pDQk53SzNCht  Creedence Clearwater Revival               1.000
# 4  00K2xasnm9pDQk53SzNCht                    Elton John               1.000

# %%
df_final = pd.merge(df_all_tracks, df_pl_art, on=['playlist_id','track_artist'], how='left')
df_final['artist_in_playlist'] = df_final.artist_in_playlist.fillna(int(0))
df_final.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc            title  \
# 0   640957      54211             1  298496035  CH3131340083      You Make Me
# 1   640957      54211             1  298496035  CH3131340084      Hey Brother
# 2   640957      54211             1  298496035  CH3131340085  Addicted To You
# 3   640957      54211             1  298496035  CH3131340086         Dear Boy
# 4   640957      54211             1  298496035  CH3131340087        Liar Liar
#
#   artist_name  artist_rank  listener_count  stream_count track_artist  \
# 0      Avicii            7            2417          2972          NaN
# 1      Avicii            7            6266          8170          NaN
# 2      Avicii            7            4278          5643          NaN
# 3      Avicii            7             371           491          NaN
# 4      Avicii            7             318           411          NaN
#
#   track_title  isrc_in_playlist  artist_in_playlist
# 0         NaN             0.000               0.000
# 1         NaN             0.000               0.000
# 2         NaN             0.000               0.000
# 3         NaN             0.000               0.000
# 4         NaN             0.000               0.000

# %%
df_final[df_final.isrc_in_playlist!=1]
# Out:
#                     playlist_id       playlist_name user_gender  \
# 0        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 1        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 2        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 3        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 4        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 5        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 6        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 7        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 8        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 9        37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 10       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 11       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 12       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 13       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 14       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 15       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 16       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 17       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 18       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 19       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 20       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 21       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 22       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 23       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 24       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 25       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 26       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 27       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 28       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# 29       37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female
# ...                         ...                 ...         ...
# 3567782  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567783  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567784  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567785  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567786  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567787  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567788  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567789  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567790  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567791  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567792  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567793  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567794  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567796  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567797  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567798  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567799  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567800  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567801  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567802  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567803  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567804  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567805  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567806  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567807  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567808  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567809  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567810  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567812  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
# 3567813  37i9dQZF1DX68H8ZujdnN7      ’80s Hard Rock      female
#
#         user_age_group  streams  listeners  rank_streams  artist_id  \
# 0                25-34   640957      54211             1  298496035
# 1                25-34   640957      54211             1  298496035
# 2                25-34   640957      54211             1  298496035
# 3                25-34   640957      54211             1  298496035
# 4                25-34   640957      54211             1  298496035
# 5                25-34   640957      54211             1  298496035
# 6                25-34   640957      54211             1  298496035
# 7                25-34   640957      54211             1  298496035
# 8                25-34   640957      54211             1  298496035
# 9                25-34   640957      54211             1  298496035
# 10               25-34   640957      54211             1  298496035
# 11               25-34   640957      54211             1  298496035
# 12               25-34   640957      54211             1  298496035
# 13               25-34   640957      54211             1  298496035
# 14               25-34   640957      54211             1  298496035
# 15               25-34   640957      54211             1  298496035
# 16               25-34   640957      54211             1  298496035
# 17               25-34   640957      54211             1  298496035
# 18               25-34   640957      54211             1  298496035
# 19               25-34   640957      54211             1  298496035
# 20               25-34   640957      54211             1  298496035
# 21               25-34   640957      54211             1  298496035
# 22               25-34   640957      54211             1  298496035
# 23               25-34   640957      54211             1  298496035
# 24               25-34   640957      54211             1  298496035
# 25               25-34   640957      54211             1  298496035
# 26               25-34   640957      54211             1  298496035
# 27               25-34   640957      54211             1  298496035
# 28               25-34   640957      54211             1  298496035
# 29               25-34   640957      54211             1  298496035
# ...                ...      ...        ...           ...        ...
# 3567782            65+       52         20            16  369659529
# 3567783            65+       52         20            16  281070699
# 3567784            65+       52         20            16  281070699
# 3567785            65+       52         20            16  281070699
# 3567786            65+       52         20            16  464296584
# 3567787            65+       52         20            16  464296584
# 3567788            65+       52         20            16    1001750
# 3567789            65+       52         20            16    1001750
# 3567790            65+       52         20            16    1001750
# 3567791            65+       52         20            16  320569549
# 3567792            65+       52         20            16  320569549
# 3567793            65+       52         20            16  320569549
# 3567794            65+       52         20            16  320569549
# 3567796            65+       52         20            16      90895
# 3567797            65+       52         20            16   78257321
# 3567798            65+       52         20            16   78257321
# 3567799            65+       52         20            16    2083606
# 3567800            65+       52         20            16     909253
# 3567801            65+       52         20            16     360391
# 3567802            65+       52         20            16  290242959
# 3567803            65+       52         20            16  290242959
# 3567804            65+       52         20            16  290242959
# 3567805            65+       52         20            16      93818
# 3567806            65+       52         20            16     122615
# 3567807            65+       52         20            16     122615
# 3567808            65+       52         20            16  260414340
# 3567809            65+       52         20            16  260414340
# 24                959          NaN         NaN             0.000
# 25              12437          NaN         NaN             0.000
# 26                102          NaN         NaN             0.000
# 27                250          NaN         NaN             0.000
# 28               2417          NaN         NaN             0.000
# 29               1988          NaN         NaN             0.000
# ...               ...          ...         ...               ...
# 3567782           245          NaN         NaN             0.000
# 3567783           113          NaN         NaN             0.000
# 3567784           147          NaN         NaN             0.000
# 3567785            12          NaN         NaN             0.000
# 3567786            13          NaN         NaN             0.000
# 3567787            46          NaN         NaN             0.000
# 3567788            11          NaN         NaN             0.000
# 3567789           149          NaN         NaN             0.000
# 3567790            32          NaN         NaN             0.000
# 3567791             9          NaN         NaN             0.000
# 3567792            34          NaN         NaN             0.000
# 3567793             5          NaN         NaN             0.000
# 3567794            56          NaN         NaN             0.000
# 3567796           111          NaN         NaN             0.000
# 3567797            27          NaN         NaN             0.000
# 3567798            10          NaN         NaN             0.000
# 3567799             6          NaN         NaN             0.000
# 3567800           125          NaN         NaN             0.000
# 3567801            66          NaN         NaN             0.000
# 3567802            12          NaN         NaN             0.000
# 3567803             6          NaN         NaN             0.000
# 3567804             9          NaN         NaN             0.000
# 3567805             5          NaN         NaN             0.000
# 3567806             8          NaN         NaN             0.000
# 3567807            12          NaN         NaN             0.000
# 3567808            14          NaN         NaN             0.000
# 3567809            70          NaN         NaN             0.000
# 3567810            29          NaN         NaN             0.000
# 3567812             5          NaN         NaN             0.000
# 3567813            10          NaN         NaN             0.000
#
#          artist_in_playlist
# 0                     0.000
# 1                     0.000
# 2                     0.000
# 3                     0.000
# 4                     0.000
# 5                     0.000
# 6                     0.000
# 7                     0.000
# 8                     0.000
# 9                     0.000
# 10                    0.000
# 11                    0.000
# 12                    0.000
# 13                    0.000
# 14                    0.000
# 15                    0.000
# 16                    0.000
# 17                    0.000
# 18                    0.000
# 19                    0.000
# 20                    0.000
# 21                    0.000
# 22                    0.000
# 23                    0.000
# 24                    0.000
# 25                    0.000
# 26                    0.000
# 27                    0.000
# 28                    0.000
# 29                    0.000
# ...                     ...
# 3567782               0.000
# 3567783               0.000
# 3567784               0.000
# 3567785               0.000
# 3567786               0.000
# 3567787               0.000
# 3567788               0.000
# 3567789               0.000
# 3567790               0.000
# 3567791               0.000
# 3567792               0.000
# 3567793               0.000
# 3567794               0.000
# 3567796               0.000
# 3567797               0.000
# 3567798               0.000
# 3567799               0.000
# 3567800               0.000
# 3567801               0.000
# 3567802               0.000
# 3567803               0.000
# 3567804               0.000
# 3567805               0.000
# 3567806               0.000
# 3567807               0.000
# 3567808               0.000
# 3567809               0.000
# 3567810               0.000
# 3567812               0.000
# 3567813               0.000
#
# [3561193 rows x 18 columns]

# %%
df_final.to_gbq(destination_table='playlist_pitching_analytics.final_apple_suggestions', project_id='umg-comm-tech-dev',
             if_exists='replace')
# Out:
# 1it [00:45, 45.93s/it]

# %% [markdown]
# ### And now over to the dashboard!
# ![](https://media.giphy.com/media/236WrWu95GphLreE2i/giphy.gif)
