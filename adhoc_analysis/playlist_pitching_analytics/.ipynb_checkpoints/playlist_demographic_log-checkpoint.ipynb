# %%
import pandas as pd
from pandas.io import gbq

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# #### Get Spotify playlists of interest

# %%
get_throwback_in_uk_browse = """
SELECT
  category_name,
  playlist_id,
  playlist_name
FROM
  `umg-alpha.spotify.spotify_playlist_browse`
WHERE
  owner_id = "spotify"
  AND territory = "GB"
GROUP BY
  1,
  2,
  3
"""

# %% [markdown]
# #### Get the demographics that are listening to these Spotify playlists
#
# Rank each demographic audience by the number of streams they do from each playlist

# %%
get_spotify_demographics = """
WITH
  playlists AS (
  SELECT
    category_name,
    playlist_id,
    playlist_name
  FROM
    `umg-comm-tech-dev.playlist_pitching_analytics.top_browse_uk_playlists`
  GROUP BY
    1,
    2,
    3)
SELECT
  category_name,
  playlist_id,
  playlist_name,
  user_country_name,
  user_gender,
  user_age,
  s.user_age_group,
  COUNT(*) AS streams,
  COUNT(DISTINCT user_id) AS listeners
FROM
  playlists p
LEFT JOIN
  `umg-edw.spotify.streams` s
ON
  p.playlist_id=REGEXP_EXTRACT(s.source_uri,r'playlist:(.*)')
WHERE
  s.stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 21 DAY)
  AND s.stream_date < CURRENT_DATE()
  AND s.user_country_code = "GB"
  AND s.user_gender != ''
  AND s.user_age IS NOT NULL
GROUP BY
  category_name,
  playlist_id,
  playlist_name,
  user_country_name,
  user_gender,
  user_age,
  s.user_age_group
"""

# %%
spotify_demographic_groups = """
SELECT
  playlist_id,
  playlist_name,
  user_gender,
  user_age_group,
  SUM(streams) AS streams,
  SUM(listeners) AS listeners,
  RANK() OVER(PARTITION BY playlist_name ORDER BY SUM(streams) DESC) AS rank_streams
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.demographics_spotify`
WHERE
  user_gender != ''
  AND user_age IS NOT NULL
GROUP BY
  playlist_id,
  playlist_name,
  user_gender,
  user_age_group
"""

# %%
sp_demographics = gbq.read_gbq(spotify_demographic_groups, project_id='umg-comm-tech-dev', dialect='standard')

# %%
sp_demographics.head()
# Out:
#               playlist_id      playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 1  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          25-34
# 2  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          18-24
# 3  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          35-44
# 4  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          18-24
#
#    streams  listeners  rank_streams
# 0   595940      36506             1
# 1   489520      29334             2
# 2   333020      25988             3
# 3   230230      12692             4
# 4   212208      15558             5

# %%
sp_demographics=sp_demographics[sp_demographics.user_age_group!="Unknown"]

# %% [markdown]
# #### Checking the audiences for these playlists and their relative distribution

# %%
by_gender_age = sp_demographics.groupby(by=['user_gender','user_age_group'])

# %%
df_dem_sp = pd.DataFrame(by_gender_age.streams.sum())
df_dem_sp['listeners'] = by_gender_age.listeners.sum()
df_dem_sp['playlist_listens']=by_gender_age.playlist_id.nunique()

# %%
df_dem_sp = df_dem_sp.reset_index()
df_dem_sp.head()
# Out:
#   user_gender user_age_group   streams  listeners  playlist_listens
# 0      female           0-12     12833       1462               262
# 1      female          13-17   6859474     971345              1299
# 2      female          18-24  52941181    6440834              1535
# 3      female          25-34  62334203    6504844              1580
# 4      female          35-44  21646456    2220899              1536

# %%
fig = plt.figure(figsize=(16,8))

cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sns.scatterplot(data=df_dem_sp, x='user_age_group', y='streams', size='listeners', sizes=(50,250),
                style='user_gender', hue='listeners', legend="full",
                palette="Set2")

plt.show()

# %% [markdown]
# Demographics is nostly as expected. Most numerous audiences are both men and women between 25-34, then 18-24 (notably girls more than boys), then 35-44s, 45-54th, etc. Interestingly 45-54 year olds have the same amount opf listeners as 55-64 year olds, but the former generate significantly more streams.

# %% [markdown]
# #### Get the ranking of ALL artists on Apple for each of our demographic groups...

# %%
apple_artist_ranks_global = """
SELECT
  apple_artist_id,
  artist_name,
  user_gender,
  user_age_group,
  SUM(stream_count) AS streams,
  SUM(listener_count) AS listeners,
  RANK() OVER(PARTITION BY user_gender,user_age_group ORDER BY SUM(stream_count) DESC) AS artist_rank
FROM
  `umg-edw.apple_music.daily_artist_demographics`
WHERE stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 7 DAY)
  AND stream_date < CURRENT_DATE()
  AND user_country_code ="GB"
  GROUP BY
  apple_artist_id,
  artist_name,
  user_gender,
  user_age_group
"""

# %% [markdown]
# #### ...and then select our top 80 catalogue artists, their rankings for each demographic and their tracks

# %%
apple_artist_content_demographic = """
SELECT
  artist_id,
  isrc,
  title,
  d.artist_name,
  d.user_gender,
  d.user_age_group,
  r.artist_rank,
  SUM(listener_count) AS listener_count,
  SUM(stream_count) AS stream_count
FROM
  `umg-edw.apple_music.daily_content_demographics` d
LEFT JOIN
  `umg-comm-tech-dev.playlist_pitching_analytics.artist_global_ranking` r
ON
  d.artist_id = r.apple_artist_id
  AND d.user_gender = r.user_gender
  AND d.user_age_group = r.user_age_group
WHERE
  stream_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 180 DAY)
  AND stream_date < CURRENT_DATE()
  AND artist_id IN (
  SELECT
    artist_id_apple
  FROM
    `umg-comm-tech-dev.hundred_artist.joined_artists_track_data`
  GROUP BY
    artist_id_apple)
  AND user_country_code = "GB"
GROUP BY
  artist_id,
  isrc,
  title,
  artist_name,
  user_gender,
  user_age_group,
  r.artist_rank 
"""

# %%
global_ranking = """
SELECT
  *,
IF
  (apple_artist_id IN (
    SELECT
      artist_id_apple
    FROM
      `umg-comm-tech-dev.hundred_artist.joined_artists_track_data`
    GROUP BY
      artist_id_apple),
    1,
    0) AS in_analysis
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.artist_global_ranking`
"""

apple_demographic = gbq.read_gbq(global_ranking, project_id='umg-comm-tech-dev', dialect='standard')
apple_demographic.head()
# Out:
#         apple_artist_id            artist_name   user_gender user_age_group  \
# 0               2715720             Kanye West  Data Unknown          18-24
# 1            1258948935               M Huncho  Data Unknown          18-24
# 2            1340729773                Digga D  Data Unknown          18-24
# 3             126007084               Blueface  Data Unknown          18-24
# 4  1201228278,466059563  Jax Jones, Bebe Rexha  Data Unknown          18-24
#
#    streams  listeners  artist_rank  in_analysis
# 0     5984       2753           13            1
# 1     3922       1121           25            0
# 2     2030       1107           54            0
# 3     1662        624           63            0
# 4     1449        967           75            0

# %%
df_apple = apple_demographic[(apple_demographic.user_gender!='Data Unknown')&(apple_demographic.user_age_group!='Data Unknown')]

# %% [markdown]
# #### Let's check how popular are our top80 catalogue artists in each of the demographic

# %%
fig = plt.figure(figsize=(16,8))

sns.boxplot(data = df_apple[df_apple.in_analysis==1], x='artist_rank', y='user_age_group', hue='user_gender',
           palette="Set2")

plt.show()

# %% [markdown]
# It's fair to say that our artists are quite popular equally in all the demographics. 75% of those artists are ranked under 250 in all demographics. The least liked artist by 45-54s that has the ranking of lower than 5000s in their group is Eason Chan :)

# %% [markdown]
# ![](8ed.jpg)

# %%
df_apple[(df_apple.in_analysis==1)&(df_apple.artist_rank>5000)]
# Out:
# Empty DataFrame
# Columns: [apple_artist_id, artist_name, user_gender, user_age_group, streams, listeners, artist_rank, in_analysis]
# Index: []

# %% [markdown]
# Below is the distribution of ALL artists on Apple ranking within each demographic. Safe to say our top 80 are doing better than average

# %%
fig = plt.figure(figsize=(16,8))

sns.boxplot(data = df_apple, x='artist_rank', y='user_age_group', hue='user_gender',
           palette="Set3")

plt.show()

# %% [markdown]
# #### Getting all our artists and their songs where their respective rank in each demographic group is no lower than 250

# %%
our_ranking = """
SELECT
  *
FROM
  `umg-comm-tech-dev.playlist_pitching_analytics.apple_content_demographic`
WHERE
  artist_rank <= 250
  AND user_gender != 'Data Unknown'
  AND user_age_group != 'Data Unknown'
"""

apple_demographic_tracks = gbq.read_gbq(our_ranking, project_id='umg-comm-tech-dev', dialect='standard')
apple_demographic_tracks.head()
# Out:
#   artist_id          isrc                                            title  \
# 0   3296287  GB2100200001                                 Somebody To Love
# 1   3296287  GB2100300730  A Kind of Magic(Live At Wembley Stadium / 1986)
# 2   3296287  GB2100300730   A Kind of Magic(Live At Wembley Stadium, 1986)
# 3   3296287  GB2100300770          I Want To Break Free(Live In Rio, 1985)
# 4   3296287  GB2100301040                                    I Want It All
#
#   artist_name user_gender user_age_group  artist_rank  listener_count  \
# 0       Queen        Male          45-54            1               5
# 1       Queen        Male          45-54            1               5
# 2       Queen        Male          45-54            1             377
# 3       Queen        Male          45-54            1               5
# 4       Queen        Male          45-54            1               5
#
#    stream_count
# 0             5
# 1             7
# 2           444
# 3             5
# 4             6

# %%
sp_demographics.head()
# Out:
#               playlist_id      playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 1  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          25-34
# 2  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          18-24
# 3  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          35-44
# 4  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation        male          18-24
#
#    streams  listeners  rank_streams
# 0   595940      36506             1
# 1   489520      29334             2
# 2   333020      25988             3
# 3   230230      12692             4
# 4   212208      15558             5

# %%
sp_demographics.user_age_group.unique()
# Out:
# array(['25-34', '18-24', '35-44', '45-54', '55-64', '13-17', '65+',
#        '0-12'], dtype=object)

# %%
sp_demographics.user_gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
apple_demographic_tracks.user_age_group.unique()
# Out:
# array(['45-54', '65+', '55-64', '35-44', '25-34', '18-24'], dtype=object)

# %%
apple_demographic_tracks['user_gender'] = [str(x).lower() for x in apple_demographic_tracks.user_gender]

# %%
apple_demographic_tracks.user_gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# #### Getting together Spotify playlist demographics with apple demographics and our top80 catalogue artists' rep

# %%
df_all = pd.merge(sp_demographics,apple_demographic_tracks, on = ['user_gender', 'user_age_group'])
df_all.head()
# Out:
#               playlist_id      playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 1  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 2  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 3  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
# 4  37i9dQZF1DX1OY2Lp0bIPp  #MondayMotivation      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc  \
# 0   595940      36506             1  159260351  GBUM70900581
# 1   595940      36506             1  159260351  GBUM70900582
# 2   595940      36506             1  159260351  GBUM70900586
# 3   595940      36506             1  159260351  GBUM70900586
# 4   595940      36506             1  159260351  GBUM71026563
#
#                                        title   artist_name  artist_rank  \
# 0       Should've Said No(International Mix)  Taylor Swift            3
# 1                       Love Story(Stripped)  Taylor Swift            3
# 2                     Teardrops On My Guitar  Taylor Swift            3
# 3  Teardrops On My Guitar(International Mix)  Taylor Swift            3
# 4                                       Mine  Taylor Swift            3
#
#    listener_count  stream_count
# 0            7117          8204
# 1               5             5
# 2               5             6
# 3            7248          8395
# 4            7826          9267

# %%
df_all.to_gbq(destination_table='playlist_pitching_analytics.apple_suggestions', project_id='umg-comm-tech-dev',
             if_exists='replace')
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# #### Now checking which of these tracks and artists are already in those respective Spotify playlists

# %%
check_track_listings = """
SELECT
  playlist_id,
  track_artist,
  track_title,
  isrc
FROM
  `umg-edw.spotify.playlist_track_history`
WHERE
  playlist_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 180 DAY)
  AND playlist_date < CURRENT_DATE()
  AND playlist_id IN (
  SELECT
    playlist_id
  FROM
    `umg-comm-tech-dev.playlist_pitching_analytics.top_browse_uk_playlists`
  GROUP BY
    1)
GROUP BY
  playlist_id,
  track_artist,
  track_title,
  isrc
"""

# %%
track_listings = gbq.read_gbq(check_track_listings, project_id='umg-comm-tech-dev', dialect='standard')
track_listings['isrc_in_playlist'] = 1
track_listings.head()
# Out:
#               playlist_id      track_artist            track_title  \
# 0  37i9dQZF1DXcIme26eJxid        Ebo Taylor                 Heaven
# 1  37i9dQZF1DWSNiUduOl0uo         B*Witched           C'est La Vie
# 2  2dWfCGZguakRQagX7wM6Mi   Third Eye Blind                 Jumper
# 3  4amhCMtqsy8RE8MI4piZ84  Dinah Washington  September In the Rain
# 4  37i9dQZF1DXcIme26eJxid     Joni Haastrup              Greetings
#
#            isrc  isrc_in_playlist
# 0  DEG931150274                 1
# 1  GBBBM9802021                 1
# 2  USEE19701204                 1
# 3  USGR10200369                 1
# 4  DEG930990070                 1

# %%
df_all_tracks = pd.merge(df_all, track_listings, on=['playlist_id','isrc'], how='left')
df_all_tracks['isrc_in_playlist'] = df_all_tracks.isrc_in_playlist.fillna(int(0))
df_all_tracks.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc            title  \
# 0   640957      54211             1  298496035  CH3131340083      You Make Me
# 1   640957      54211             1  298496035  CH3131340084      Hey Brother
# 2   640957      54211             1  298496035  CH3131340085  Addicted To You
# 3   640957      54211             1  298496035  CH3131340086         Dear Boy
# 4   640957      54211             1  298496035  CH3131340087        Liar Liar
#
#   artist_name  artist_rank  listener_count  stream_count track_artist  \
# 0      Avicii            7           16923         21107          NaN
# 1      Avicii            7           55752         72143          NaN
# 2      Avicii            7           35736         46271          NaN
# 3      Avicii            7            3617          5078          NaN
# 4      Avicii            7            2742          3481          NaN
#
#   track_title  isrc_in_playlist
# 0         NaN             0.000
# 1         NaN             0.000
# 2         NaN             0.000
# 3         NaN             0.000
# 4         NaN             0.000

# %%
by_pl_art = df_all_tracks.groupby(by=['playlist_id','artist_name']).isrc_in_playlist.max()
df_pl_art = pd.DataFrame(by_pl_art).reset_index()
df_pl_art.columns = ['playlist_id','artist_name','artist_in_playlist']
df_pl_art.head()
# Out:
#               playlist_id   artist_name  artist_in_playlist
# 0  00K2xasnm9pDQk53SzNCht          2Pac               0.000
# 1  00K2xasnm9pDQk53SzNCht       50 Cent               0.000
# 2  00K2xasnm9pDQk53SzNCht          ABBA               1.000
# 3  00K2xasnm9pDQk53SzNCht          Akon               0.000
# 4  00K2xasnm9pDQk53SzNCht  Alessia Cara               0.000

# %%
df_pl_art[df_pl_art.playlist_id=='0ApdHY8K71F9WrIWbgiI2G']
# Out:
#                 playlist_id                   artist_name  artist_in_playlist
# 57   0ApdHY8K71F9WrIWbgiI2G                          2Pac               0.000
# 58   0ApdHY8K71F9WrIWbgiI2G                       50 Cent               0.000
# 59   0ApdHY8K71F9WrIWbgiI2G                          ABBA               0.000
# 60   0ApdHY8K71F9WrIWbgiI2G                 Amy Winehouse               0.000
# 61   0ApdHY8K71F9WrIWbgiI2G                        Avicii               0.000
# 62   0ApdHY8K71F9WrIWbgiI2G                      Bee Gees               1.000
# 63   0ApdHY8K71F9WrIWbgiI2G      Bob Marley & The Wailers               0.000
# 64   0ApdHY8K71F9WrIWbgiI2G                      Bon Jovi               0.000
# 65   0ApdHY8K71F9WrIWbgiI2G                   Bryan Adams               0.000
# 66   0ApdHY8K71F9WrIWbgiI2G               Chris Stapleton               0.000
# 67   0ApdHY8K71F9WrIWbgiI2G  Creedence Clearwater Revival               1.000
# 68   0ApdHY8K71F9WrIWbgiI2G                       Dr. Dre               0.000
# 69   0ApdHY8K71F9WrIWbgiI2G                Ellie Goulding               0.000
# 70   0ApdHY8K71F9WrIWbgiI2G                    Elton John               0.000
# 71   0ApdHY8K71F9WrIWbgiI2G                        Eminem               0.000
# 72   0ApdHY8K71F9WrIWbgiI2G              Enrique Iglesias               0.000
# 73   0ApdHY8K71F9WrIWbgiI2G                  Fall Out Boy               0.000
# 74   0ApdHY8K71F9WrIWbgiI2G        Florence + The Machine               0.000
# 75   0ApdHY8K71F9WrIWbgiI2G                 Frank Sinatra               1.000
# 76   0ApdHY8K71F9WrIWbgiI2G                 Guns N' Roses               0.000
# 77   0ApdHY8K71F9WrIWbgiI2G                         JAY-Z               0.000
# 78   0ApdHY8K71F9WrIWbgiI2G                  Jack Johnson               0.000
# 79   0ApdHY8K71F9WrIWbgiI2G                     James Bay               0.000
# 80   0ApdHY8K71F9WrIWbgiI2G                 Justin Bieber               0.000
# 81   0ApdHY8K71F9WrIWbgiI2G                    Kanye West               0.000
# 82   0ApdHY8K71F9WrIWbgiI2G                    Katy Perry               0.000
# 83   0ApdHY8K71F9WrIWbgiI2G                  Lana Del Rey               0.000
# 84   0ApdHY8K71F9WrIWbgiI2G                Lynyrd Skynyrd               0.000
# 85   0ApdHY8K71F9WrIWbgiI2G                   Marvin Gaye               1.000
# 86   0ApdHY8K71F9WrIWbgiI2G                     Metallica               0.000
# 87   0ApdHY8K71F9WrIWbgiI2G                Mumford & Sons               0.000
# 88   0ApdHY8K71F9WrIWbgiI2G                         Ne-Yo               0.000
# 89   0ApdHY8K71F9WrIWbgiI2G                       Nirvana               0.000
# 90   0ApdHY8K71F9WrIWbgiI2G                   Norah Jones               0.000
# 91   0ApdHY8K71F9WrIWbgiI2G                   OneRepublic               0.000
# 92   0ApdHY8K71F9WrIWbgiI2G                         Queen               0.000
# 93   0ApdHY8K71F9WrIWbgiI2G                       Rihanna               0.000
# 94   0ApdHY8K71F9WrIWbgiI2G                 Stevie Wonder               1.000
# 95   0ApdHY8K71F9WrIWbgiI2G                   Tame Impala               0.000
# 96   0ApdHY8K71F9WrIWbgiI2G                  Taylor Swift               0.000
# 97   0ApdHY8K71F9WrIWbgiI2G                The Beach Boys               1.000
# 98   0ApdHY8K71F9WrIWbgiI2G                   The Beatles               1.000
# 99   0ApdHY8K71F9WrIWbgiI2G           The Black Eyed Peas               0.000
# 100  0ApdHY8K71F9WrIWbgiI2G               The Cranberries               0.000
# 101  0ApdHY8K71F9WrIWbgiI2G                   The Killers               0.000
# 102  0ApdHY8K71F9WrIWbgiI2G                    The Police               0.000
# 103  0ApdHY8K71F9WrIWbgiI2G            The Rolling Stones               1.000
# 104  0ApdHY8K71F9WrIWbgiI2G                            U2               0.000
# 105  0ApdHY8K71F9WrIWbgiI2G                     blink-182               0.000

# %%
df_final = pd.merge(df_all_tracks, df_pl_art, on=['playlist_id','artist_name'], how='left')
df_final.head()
# Out:
#               playlist_id       playlist_name user_gender user_age_group  \
# 0  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 1  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 2  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 3  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
# 4  37i9dQZF1DWXF8Nf1uycDZ  #ThrowbackThursday      female          25-34
#
#    streams  listeners  rank_streams  artist_id          isrc            title  \
# 0   640957      54211             1  298496035  CH3131340083      You Make Me
# 1   640957      54211             1  298496035  CH3131340084      Hey Brother
# 2   640957      54211             1  298496035  CH3131340085  Addicted To You
# 3   640957      54211             1  298496035  CH3131340086         Dear Boy
# 4   640957      54211             1  298496035  CH3131340087        Liar Liar
#
#   artist_name  artist_rank  listener_count  stream_count track_artist  \
# 4496232             Helter Skelter(First Version / Take 2)  The Beatles
# 4496233  While My Guitar Gently Weeps(Acoustic Version ...  The Beatles
# 4496234                        St. Louis Blues(Studio Jam)  The Beatles
# 4496235                                   Hey Jude(Take 1)  The Beatles
# 4496236                 Yer Blues(Take 5 with Guide Vocal)  The Beatles
# 4496237  Back In the U.S.S.R.(Take 5 / Instrumental Bac...  The Beatles
# 4496238               Dear Prudence(Vocal, Guitar & Drums)  The Beatles
# 4496239   (You're So Square) Baby I Don’t Care[Studio Jam]  The Beatles
# 4496240           Helter Skelter(Second Version / Take 17)  The Beatles
# 4496241                       Step Inside Love(Studio Jam)  The Beatles
# 4496242                      Can You Take Me Back?(Take 1)  The Beatles
# 4496243                          Los Paranoias(Studio Jam)  The Beatles
# 4496244                   Happiness Is a Warm Gun(Take 19)  The Beatles
# 4496245                              Rocky Raccoon(Take 8)  The Beatles
# 4496246      Piggies(Take 12 / Instrumental Backing Track)  The Beatles
# 4496247      The Continuing Story of Bungalow Bill(Take 2)  The Beatles
# 4496248                              Julia(Two Rehearsals)  The Beatles
# 4496249           Lady Madonna(Backing Vocals from Take 3)  The Beatles
# 4496250                        Across the Universe(Take 6)  The Beatles
# 4496251                   Revolution(Unnumbered Rehearsal)  The Beatles
# 4496252   Revolution(Take 14 / Instrumental Backing Track)  The Beatles
# 4496253                   What's the New Mary Jane(Take 1)  The Beatles
# 4496254                              Blue Moon(Studio Jam)  The Beatles
#
#          artist_rank  listener_count  stream_count track_artist track_title  \
# 4487797            4            3881          4683          NaN         NaN
# 4487798            4             172           185          NaN         NaN
# 4487799            4             269           301          NaN         NaN
# 4487800            4              57            64          NaN         NaN
# 4487801            4             125           146          NaN         NaN
# 4487802            4             173           203          NaN         NaN
# 4487803            4            2655          3635          NaN         NaN
# 4487804            4            2942          3338          NaN         NaN
# 4487805            4             269           314          NaN         NaN
# 4487806            4             277           318          NaN         NaN
# 4487807            4             426           493          NaN         NaN
# 4487808            4              66            73          NaN         NaN
# 4487809            4              80            95          NaN         NaN
# 4487810            4           12489         15422          NaN         NaN
# 4487811            4             123           138          NaN         NaN
# 4487812            4             122           132          NaN         NaN
# 4487813            4            6027          7097          NaN         NaN
# 4487814            4              69            75          NaN         NaN
# 4487815            4              20            20          NaN         NaN
# 4487816            4             516           607          NaN         NaN
# 4487817            4              98           106          NaN         NaN
# 4487818            4              89            99          NaN         NaN
# 4487819            4              32            36          NaN         NaN
# 4487820            4             122           139          NaN         NaN
# 4487821            4              25            27          NaN         NaN
# 4487822            4              47            54          NaN         NaN
# 4487823            4              69            72          NaN         NaN
# 4487824            4              45            58          NaN         NaN
# 4487825            4            6628          7626          NaN         NaN
# 4487826            4            1901          2285          NaN         NaN
# ...              ...             ...           ...          ...         ...
# 4496225            4            1465          1667          NaN         NaN
# 4496226            4               5             5          NaN         NaN
# 4496227            4               5             5          NaN         NaN
# 4496228            4               5             5          NaN         NaN
# 4496229            4              11            12          NaN         NaN
# 4496230            4              10            10          NaN         NaN
