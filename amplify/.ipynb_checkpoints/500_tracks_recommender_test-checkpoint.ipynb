# %%
import numpy as np
import pandas as pd

import implicit

from google.cloud import storage

from pandas.io import gbq

import pickle

# %%
#client = storage.Client(project='umg-comm-tech-dev')
#bucket = client.get_bucket('umg-comm-tech-dev')

# %%
class MacOSFile(object):

    def __init__(self, f):
        self.f = f

    def __getattr__(self, item):
        return getattr(self.f, item)

    def read(self, n):
        # print("reading total_bytes=%s" % n, flush=True)
        if n >= (1 << 31):
            buffer = bytearray(n)
            idx = 0
            while idx < n:
                batch_size = min(n - idx, 1 << 31 - 1)
                # print("reading bytes [%s,%s)..." % (idx, idx + batch_size), end="", flush=True)
                buffer[idx:idx + batch_size] = self.f.read(batch_size)
                # print("done.", flush=True)
                idx += batch_size
            return buffer
        return self.f.read(n)

    def write(self, buffer):
        n = len(buffer)
        print("writing total_bytes=%s..." % n, flush=True)
        idx = 0
        while idx < n:
            batch_size = min(n - idx, 1 << 31 - 1)
            print("writing bytes [%s, %s)... " % (idx, idx + batch_size), end="", flush=True)
            self.f.write(buffer[idx:idx + batch_size])
            print("done.", flush=True)
            idx += batch_size


def pickle_dump(obj, file_path):
    with open(file_path, "wb") as f:
        return pickle.dump(obj, MacOSFile(f), protocol=pickle.HIGHEST_PROTOCOL)


def pickle_load(file_path):
    with open(file_path, "rb") as f:
        return pickle.load(MacOSFile(f))

# %%
model = pickle_load('/Users/meshchd/Downloads/saved_model.pkl')

# %%
df = pd.read_csv('/Users/meshchd/Downloads/500UMeISRCs.csv')

# %%
df.head()
# Out:
#            isrc                  artist                 title
# 0  GBAAA8500070            Simple Minds     Alive And Kicking
# 1  USUG11401961                 Madonna     Bitch I'm Madonna
# 2  GBUM71028665             James Blake    Limit To Your Love
# 3  USCH38400069             Pat Benatar  Shadows Of The Night
# 4  USPR36905204  The Velvet Underground        Pale Blue Eyes

# %%
df.to_gbq('amplify.ume500_isrcs', project_id='umg-comm-tech-dev', if_exists='replace')
# Out:
# 1it [00:05,  5.35s/it]

# %%
get_existing_tags = """
SELECT
  isrc,
  confidence,
  path,
  source,
  taxonomy_node_id,
  value
FROM
  `umg-metadata.ircam.amplify_tem_v3_3_v`
WHERE
  isrc IN (
  SELECT
    isrc
  FROM
    `umg-comm-tech-dev.amplify.ume500_isrcs`
  GROUP BY
    isrc)
"""

# %%
tags = gbq.read_gbq(get_existing_tags, project_id='umg-comm-tech-dev', dialect='standard')

# %%
tags.head()
# Out:
#            isrc  confidence                                         path  \
# 0  GRE018000028    1.000000                         Anatomy/Harmony/Root
# 1  GRE018000028    0.544659                               Energy/Emotion
# 2  GRE018000028    0.544659                      Energy/Emotion/Negative
# 3  GRE018000028    1.000000                      Energy/Intensity/Medium
# 4  GRE018000028    0.631046  Performance/Ensemble/Ensemble Configuration
#
#    source                      taxonomy_node_id                  value
# 0    Auto  acf5ddcf-0890-4647-8823-16522e66b541                      A
# 1    Auto  3adcefb7-b1c1-4f4d-a40c-4032c8d35aca               Negative
# 2    Auto  77822969-740e-4f56-9ea0-09de404dc071                    Sad
# 3  Manual  0b5909f2-c61f-43f2-a51d-a473fb01a768       Medium Intensity
# 4    Auto  6df35aeb-4c6f-448e-8d14-1967aa24a098  Voice & Accompaniment

# %%
tags.describe(include='all')
# Out:
#                 isrc    confidence                                   path  \
# count          30518  30518.000000                                  30518
# unique           491           NaN                                    100
# top     GBF075820000           NaN  Performance/Ensemble/Ensemble Section
# freq             274           NaN                                   4180
# mean             NaN      0.852100                                    NaN
# std              NaN      0.180539                                    NaN
# min              NaN      0.301012                                    NaN
# 25%              NaN      0.732352                                    NaN
# 50%              NaN      0.939958                                    NaN
# 75%              NaN      1.000000                                    NaN
# max              NaN      1.000000                                    NaN
#
#        source                      taxonomy_node_id       value
# count   30518                                 30518       30518
# unique      2                                   256         733
# top      Auto  ca8d3fea-e3cc-4c38-abd3-0a32e49a311f  Percussion
# freq    29948                                  1062        1775
# mean      NaN                                   NaN         NaN
# std       NaN                                   NaN         NaN
# min       NaN                                   NaN         NaN
# 25%       NaN                                   NaN         NaN
# 50%       NaN                                   NaN         NaN
# 75%       NaN                                   NaN         NaN
# max       NaN                                   NaN         NaN

# %%
tags.groupby(by='isrc').value.count().describe()
# Out:
# count    491.000000
# mean      62.154786
# std       26.924090
# min        6.000000
# 25%       50.000000
# 50%       58.000000
# 75%       84.000000
# max      274.000000
# Name: value, dtype: float64

# %%
tags_in_recommender = [isrc if isrc in model.isrcs else '' for isrc in tags.isrc.unique()]

# %%
tags_in_recommender = list(set(tags_in_recommender))

# %%
len(tags_in_recommender)
# Out:
# 168

# %%
tags_in_recommender[1]
# Out:
# 'GBAYE8200083'

# %%
def get_similar_items(seed_isrc, n=100):
    
    item_id = model.isrcs.index(seed_isrc)

    # Get the item row for the isrc
    item_vec = model.isrc_vecs[item_id].T

    # Calculate the similarity score
    # and select the top 100 most similar.
    scores = model.isrc_vecs.dot(item_vec).reshape(1,-1)[0]
    top_100 = np.argsort(scores)[::-1][:n]
    
    similar_isrcs = []
    artists = []
    names = []
    isrc_scores = []
    
    for idx in list(top_100):

        isrc = model.isrcs[idx]
        lookup = model.isrc_lookup[model.isrc_lookup.isrc==isrc].iloc[0]
    
        similar_isrcs.append(isrc)
        artists.append(lookup[1])
        names.append(lookup[2])
        isrc_scores.append(scores[idx])
        
    similar = pd.DataFrame({'isrc': similar_isrcs, 'artist': artists, 'track_name': names, 'score': isrc_scores})
    similar['seed_isrc']=seed_isrc
    
    return similar

# %%
df = pd.DataFrame(columns = ['isrc','artist','track_name','score','seed_isrc'])

for isrc in tags_in_recommender[1:]:
    df=pd.concat([df,get_similar_items(isrc)], ignore_index=True)

# %%
df.shape
# Out:
# (16700, 5)

# %%
df.head()
# Out:
#            isrc           artist  \
# 0  GBAYE8200083     Thomas Dolby
# 1  CHD771800006  Alejandro Reyes
# 2  ROARA1700019            Andra
# 3  USSD11900123   Descemer Bueno
# 4  ushm20708304   Emile Pandolfi
#
#                                           track_name     score     seed_isrc
# 0                        She Blinded Me With Science  0.012011  GBAYE8200083
# 1                                          Solamente  0.010726  GBAYE8200083
# 2                                             Shukar  0.010030  GBAYE8200083
# 3  Nos Fuimos Lejos (feat. Ece Seçkin & El Micha)...  0.009937  GBAYE8200083
# 4              Once Upon a December (from Anastasia)  0.009774  GBAYE8200083

# %%
df.to_gbq('amplify.ume500_100similar', project_id='umg-comm-tech-dev', if_exists='replace')
# Out:
# 1it [00:00,  6.21it/s]

# %%
get_existing_tags_similar = """
SELECT
  isrc,
  confidence,
  path,
  source,
  taxonomy_node_id,
  value
FROM
  `umg-metadata.ircam.amplify_tem_v3_3_v`
WHERE
  isrc IN (
  SELECT
    isrc
  FROM
    `umg-comm-tech-dev.amplify.ume500_100similar`
  GROUP BY
    isrc)
"""

# %%
tags_similar = gbq.read_gbq(get_existing_tags_similar, project_id='umg-comm-tech-dev', dialect='standard')

# %%
tags_similar.head()
# Out:
#            isrc  confidence                  path source  \
# 0  UKG4Y1700048    1.000000  Anatomy/Harmony/Root   Auto
# 1  UKG4Y1700048    0.927146                 Genre   Auto
# 2  QZG4T1900011    1.000000  Anatomy/Harmony/Root   Auto
# 3  QZG4T1900011    0.912205                 Genre   Auto
# 4  QZG4T1900011    0.912205             Genre/R&B   Auto
#
#                        taxonomy_node_id             value
# 0  e5d51dc7-8a75-4cd8-8efd-a3f18eddc866             Bb/A#
# 1  195e1e65-82e9-4a49-96de-fca22301027e        Electronic
# 2  71fade6b-1c0e-4b10-9ee3-2178a7548c86                 G
# 3  3ffa3c14-6b46-4295-9618-77b1de08c9b6               R&B
# 4  d460dddd-2bf3-434b-81de-86b5a60d285a  Contemporary R&B

# %%
tags_similar.groupby(by='isrc').value.count().describe()
# Out:
# count    1235.000000
# mean       79.149798
# std        70.874631
# min         6.000000
# 25%        50.000000
# 50%        60.000000
# 75%        90.000000
# max      1118.000000
# Name: value, dtype: float64

# %%
original_count = pd.DataFrame(tags.groupby(by='isrc').value.nunique()).reset_index()
original_count.head()
# Out:
#            isrc  value
# 0  ARA730600041     26
# 1  ATT259608440     33
# 2  ATUM71500361     26
# 3  AUAB00050243     30
# 4  AUAB00500696     30

# %%
similar_count = pd.DataFrame(tags_similar.groupby(by='isrc').value.nunique()).reset_index()
similar_count.head()
# Out:
#            isrc  value
# 0  ARF410600414     30
# 1  ATB158500018     18
# 2  ATPB51801014     26
# 3  AUAP08200012     30
# 4  AUBEC1601210     23

# %%
df_all = pd.merge(df, original_count, left_on='seed_isrc', right_on='isrc', suffixes=['','_original'])
df_all.head()
# Out:
#            isrc           artist  \
# 0  GBAYE8200083     Thomas Dolby
# 1  CHD771800006  Alejandro Reyes
# 2  ROARA1700019            Andra
# 3  USSD11900123   Descemer Bueno
# 4  ushm20708304   Emile Pandolfi
#
#                                           track_name     score     seed_isrc  \
# 0                        She Blinded Me With Science  0.012011  GBAYE8200083
# 1                                          Solamente  0.010726  GBAYE8200083
# 2                                             Shukar  0.010030  GBAYE8200083
# 3  Nos Fuimos Lejos (feat. Ece Seçkin & El Micha)...  0.009937  GBAYE8200083
# 4              Once Upon a December (from Anastasia)  0.009774  GBAYE8200083
#
#   isrc_original  value
# 0  GBAYE8200083     30
# 1  GBAYE8200083     30
# 2  GBAYE8200083     30
# 3  GBAYE8200083     30
# 4  GBAYE8200083     30

# %%
df_all = pd.merge(df_all, similar_count, on='isrc', suffixes=['','_similar'])
df_all.head()
# Out:
#            isrc              artist                         track_name  \
# 0  GBAYE8200083        Thomas Dolby        She Blinded Me With Science
# 1  USMC18416586  Harold Faltermeyer  Axel F - From "Beverly Hills Cop"
# 2  USMC18416586  Harold Faltermeyer  Axel F - From "Beverly Hills Cop"
# 3  USMC18416586  Harold Faltermeyer  Axel F - From "Beverly Hills Cop"
# 4  USMC18416586  Harold Faltermeyer  Axel F - From "Beverly Hills Cop"
#
#       score     seed_isrc isrc_original  value  value_similar
# 0  0.012011  GBAYE8200083  GBAYE8200083     30             30
# 1  0.009662  GBAYE8200083  GBAYE8200083     30             22
# 2  0.009969  USAR18400004  USAR18400004     28             22
# 3  0.006738  USCH38400069  USCH38400069     31             22
# 4  0.001448  GBUM71601386  GBUM71601386      6             22

# %%
df_all.to_gbq('amplify.ume500_initial_and_similar', project_id='umg-comm-tech-dev', if_exists='replace')
# Out:
# 1it [00:00,  3.79it/s]

# %%
df_all[df_all.seed_isrc=='GBAYE8200083'].head(20)
# Out:
#              isrc                   artist  \
# 0    GBAYE8200083             Thomas Dolby
# 1    USMC18416586       Harold Faltermeyer
# 5    USMO10000307                 Rockwell
# 6    GBAYE8200051              Duran Duran
# 7    USWB10000035                     DEVO
# 8    USAR18400008          Ray Parker, Jr.
# 10   GBUM71807978              James Blake
# 135  ATB158500018                    Falco
# 136  FR0LO1800026        Jean-Michel Jarre
# 288  DEUM70703331          Dschinghis Khan
# 289  USMC18519112             Oingo Boingo
# 290  JPTO00002076           Tomoyasu Hotei
# 301  USAR18400117          Ray Parker, Jr.
# 302  USRC18207933  Daryl Hall & John Oates
# 304  USWB19901100               The B-52's
# 305  NOLEH1801010                     Fieh
# 387  GBAZP9700067               Gary Numan
# 388  GBAYK8100051             The Specials
# 389  GBARL8200001              Bow Wow Wow
# 390  GBAAP0200005             Bronski Beat
#
#                              track_name     score     seed_isrc isrc_original  \
# 0           She Blinded Me With Science  0.012011  GBAYE8200083  GBAYE8200083
# 1     Axel F - From "Beverly Hills Cop"  0.009662  GBAYE8200083  GBAYE8200083
# 5                Somebody's Watching Me  0.009524  GBAYE8200083  GBAYE8200083
# 6                  Hungry Like The Wolf  0.009520  GBAYE8200083  GBAYE8200083
# 7                               Whip It  0.009310  GBAYE8200083  GBAYE8200083
# 8    Ghostbusters - From "Ghostbusters"  0.009173  GBAYE8200083  GBAYE8200083
# 10                 Barefoot In The Park  0.009098  GBAYE8200083  GBAYE8200083
# 135      Rock Me Amadeus - The Gold Mix  0.009075  GBAYE8200083  GBAYE8200083
# 136       ROBOTS DON'T CRY (movement 3)  0.009005  GBAYE8200083  GBAYE8200083
# 288                              Moskau  0.008998  GBAYE8200083  GBAYE8200083
# 289                       Weird Science  0.008994  GBAYE8200083  GBAYE8200083
# 290    Battle Without Honor Or Humanity  0.008864  GBAYE8200083  GBAYE8200083
# 301                        Ghostbusters  0.008839  GBAYE8200083  GBAYE8200083
# 302                            Maneater  0.008832  GBAYE8200083  GBAYE8200083
# 304                        Rock Lobster  0.008810  GBAYE8200083  GBAYE8200083
# 305                                  25  0.008797  GBAYE8200083  GBAYE8200083
# 387                                Cars  0.008724  GBAYE8200083  GBAYE8200083
# 388                          Ghost Town  0.008709  GBAYE8200083  GBAYE8200083
# 389                        I Want Candy  0.008708  GBAYE8200083  GBAYE8200083
# 390                       Smalltown Boy  0.008682  GBAYE8200083  GBAYE8200083
#
#      value  value_similar
# 0       30             30
# 1       30             22
# 5       30             28
# 6       30             36
# 7       30             26
# 8       30             31
# 10      30             21
# 135     30             18
# 136     30             25
# 288     30             23
# 289     30             30
# 290     30             27
# 301     30             29
# 302     30             82
# 304     30             29
# 305     30             84
# 387     30             27
# 388     30             22
# 389     30             28
# 390     30             27

# %%
tags[tags.isrc=='GBAYE8200083'].value.unique()
# Out:
# array(['C', 'Attitude', 'Sentimental', 'Pop Band', 'Low Intensity',
#        'Steady', 'No Strings', 'No Winds', 'Wind Section', 'Positive',
#        'Percussion', 'Romantic', 'Major', 'Drum Set', 'No Choir',
#        'Medium', 'Low', 'High Vocal Range', 'Simple', 'Persistent Pulse',
#        'Slow', '4', 'String Section', 'Dynamic', 'Has Percussion',
#        'Electric', '130.54', 'Light', 'Choir', 'Voice & Music'],
#       dtype=object)

# %%
tags = tags.drop_duplicates()

# %%
tags[tags.isrc=='GBAYE8200083']
# Out:
#                isrc  confidence  \
# 791    GBAYE8200083    1.000000
# 792    GBAYE8200083    0.472720
# 793    GBAYE8200083    0.472720
# 794    GBAYE8200083    0.632485
# 4117   GBAYE8200083    0.746098
# 4675   GBAYE8200083    0.948199
# 5246   GBAYE8200083    0.736112
# 6069   GBAYE8200083    0.980639
# 7260   GBAYE8200083    0.980639
# 9015   GBAYE8200083    0.359032
# 9884   GBAYE8200083    0.980921
# 12104  GBAYE8200083    0.359032
# 13002  GBAYE8200083    1.000000
# 13763  GBAYE8200083    0.758855
# 14909  GBAYE8200083    0.966222
# 15771  GBAYE8200083    0.582403
# 16273  GBAYE8200083    0.746098
# 16622  GBAYE8200083    0.713945
# 17315  GBAYE8200083    1.000000
# 18207  GBAYE8200083    0.948199
# 18721  GBAYE8200083    0.416170
# 19565  GBAYE8200083    1.000000
# 21874  GBAYE8200083    0.736112
# 22835  GBAYE8200083    0.625394
# 23569  GBAYE8200083    0.980921
# 24590  GBAYE8200083    0.980921
# 25439  GBAYE8200083    0.752488
# 26336  GBAYE8200083    1.000000
# 27294  GBAYE8200083    0.758855
# 27768  GBAYE8200083    0.966222
# 28761  GBAYE8200083    0.892775
#
#                                                     path source  \
# 791                                 Anatomy/Harmony/Root   Auto
# 792                                       Energy/Emotion   Auto
# 793                              Energy/Emotion/Attitude   Auto
# 794          Performance/Ensemble/Ensemble Configuration   Auto
# 4117                                Energy/Intensity/Low   Auto
# 4675        Anatomy/Rhythm & Time/Tempo/Persistent Pulse   Auto
# 5246   Performance/Ensemble/Ensemble Section/String S...   Auto
# 6069   Performance/Ensemble/Ensemble Section/Wind Sec...   Auto
# 7260               Performance/Ensemble/Ensemble Section   Auto
# 9015                                      Energy/Emotion   Auto
# 9884               Performance/Ensemble/Ensemble Section   Auto
# 12104                            Energy/Emotion/Positive   Auto
# 13002                               Anatomy/Harmony/Mode   Auto
# 13763                             Performance/Instrument   Auto
# 14909        Performance/Ensemble/Ensemble Section/Choir   Auto
# 15771                  Anatomy/Rhythm & Time/Tempo/Speed   Auto
# 16273                                   Energy/Intensity   Auto
# 16622                      Performance/Voice/Vocal Range   Auto
# 17315                        Anatomy/Rhythm & Time/Meter   Auto
# 18207                        Anatomy/Rhythm & Time/Tempo   Auto
# 18721                  Anatomy/Rhythm & Time/Tempo/Speed   Auto
# 19565                 Anatomy/Rhythm & Time/Meter/Simple   Auto
# 21874              Performance/Ensemble/Ensemble Section   Auto
# 22835                    Anatomy/Structure/Dynamic Shape   Auto
# 23569   Performance/Ensemble/Ensemble Section/Percussion   Auto
# 24590                             Performance/Instrument   Auto
# 25439               Performance/Ensemble/Ensemble Timbre   Auto
# 26336                          Anatomy/Rhythm & Time/BPM   Auto
# 27294                    Performance/Performer/Intensity   Auto
# 27768              Performance/Ensemble/Ensemble Section   Auto
# 28761                                Anatomy/Arrangement   Auto
#
#                            taxonomy_node_id             value
# 791    aebebe3e-ac1f-44e2-a344-692afb387fa6                 C
# 792    b97db862-5042-40c6-b6c7-8d3f9b53e9fc          Attitude
# 793    5eb43531-159c-44d2-bd75-08a8fa80f2c4       Sentimental
# 794    ddb813d8-3410-43ce-8e1a-f2c9b047ff49          Pop Band
# 4117   0045b3a0-e3ce-439a-905b-50ab4e25f578     Low Intensity
# 4675   0b1ef0c0-ebbe-46e8-afb6-0b4a3ad6ff21            Steady
# 5246   0d8dbaa8-69d3-4dce-8dd5-993b10fa3a03        No Strings
# 6069   137e3494-28f1-44e0-ad02-625abe2d47bf          No Winds
# 7260   1d145636-1083-46f0-aca0-7b509e892f3e      Wind Section
# 9015   27be0bbf-e3fe-49a6-9c5e-0e26b8e4435b          Positive
# 9884   29d4bed1-37af-4ecc-bba7-8917fd9e389f        Percussion
# 12104  5c55f7dd-506b-4310-9cfc-fd9242aa884e          Romantic
# 13002  600e609b-d06f-46bd-a5e9-40088309315b             Major
# 13763  64b277d8-6f18-40c3-9d02-7d966012d0cb          Drum Set
# 14909  7523ec70-c471-47a4-8837-8f1e595cf7e6          No Choir
# 15771  76c2f4a0-9e78-4c48-b9bf-4864e9957c3a            Medium
# 16273  787fee32-5747-41b1-87b3-aa319bb66478               Low
# 16622  78a59e57-ceb2-4512-b469-d3826ef4d863  High Vocal Range
# 17315  7c6cf0b3-ed30-4426-9482-ccf6ba4d8d57            Simple
# 18207  7da10b5a-62c3-404b-997c-51a1547b0827  Persistent Pulse
# 18721  81d65be3-1438-43fb-9ca1-82414d1e9930              Slow
# 19565  8beb64e1-7287-4f05-b225-f1a31ba4e333                 4
# 21874  9d56e164-978d-461e-931e-2b6639842b20    String Section
# 22835  9db35582-5cb7-45ea-9bc3-1534c1b5bd82           Dynamic
# 23569  ab89b187-246b-42bd-8eac-93bde9ea9a98    Has Percussion
# 24590  ada66447-1442-4b2d-afca-4dfc1b66ac32        Percussion
# 25439  b1eb3b83-adb1-4cd0-93fd-c1fe815ffed4          Electric
# 26336  ca8d3fea-e3cc-4c38-abd3-0a32e49a311f            130.54
# 27294  d064ff52-ad7b-4933-a6e3-4a4001331acc             Light
# 27768  da57a61a-dc49-4ee3-b62b-df73365274d4             Choir
# 28761  df112352-99b1-4cda-b46b-6b68d97ed796     Voice & Music

# %%
tags_no_dupl = pd.DataFrame(columns=tags.columns)

for isrc in tags.isrc.unique():
    
    tag_slice = tags[tags.isrc==isrc]

    paths = tag_slice.path.unique()

    dupl = []

    for i, path in enumerate(paths):
        for j, path2 in enumerate(paths):
            if i!=j:
                if path2 in path:
                    dupl.append(path2)
                
    duplicates = list(set(dupl))
    
    slice_no_dupl = tag_slice[~tag_slice.path.isin(duplicates)]
    
    tags_no_dupl = pd.concat([tags_no_dupl,slice_no_dupl], ignore_index=True)

# %%
tags_no_dupl[tags_no_dupl.isrc=='GBAYE8200083'].sort_values(by='confidence', ascending=False)
# Out:
#               isrc  confidence  \
# 3042  GBAYE8200083    1.000000
# 3061  GBAYE8200083    1.000000
# 3056  GBAYE8200083    1.000000
# 3050  GBAYE8200083    1.000000
# 3059  GBAYE8200083    0.980921
# 3058  GBAYE8200083    0.980921
# 3048  GBAYE8200083    0.980639
# 3052  GBAYE8200083    0.966222
# 3046  GBAYE8200083    0.948199
# 3063  GBAYE8200083    0.892775
# 3051  GBAYE8200083    0.758855
# 3062  GBAYE8200083    0.758855
# 3060  GBAYE8200083    0.752488
# 3045  GBAYE8200083    0.746098
# 3047  GBAYE8200083    0.736112
# 3054  GBAYE8200083    0.713945
# 3044  GBAYE8200083    0.632485
# 3057  GBAYE8200083    0.625394
# 3053  GBAYE8200083    0.582403
# 3043  GBAYE8200083    0.472720
# 3055  GBAYE8200083    0.416170
# 3049  GBAYE8200083    0.359032
#
#                                                    path source  \
# 3042                               Anatomy/Harmony/Root   Auto
# 3061                          Anatomy/Rhythm & Time/BPM   Auto
# 3056                 Anatomy/Rhythm & Time/Meter/Simple   Auto
# 3050                               Anatomy/Harmony/Mode   Auto
# 3059                             Performance/Instrument   Auto
# 3058   Performance/Ensemble/Ensemble Section/Percussion   Auto
# 3048  Performance/Ensemble/Ensemble Section/Wind Sec...   Auto
# 3052        Performance/Ensemble/Ensemble Section/Choir   Auto
# 3046       Anatomy/Rhythm & Time/Tempo/Persistent Pulse   Auto
# 3063                                Anatomy/Arrangement   Auto
# 3051                             Performance/Instrument   Auto
# 3062                    Performance/Performer/Intensity   Auto
# 3060               Performance/Ensemble/Ensemble Timbre   Auto
# 3045                               Energy/Intensity/Low   Auto
# 3047  Performance/Ensemble/Ensemble Section/String S...   Auto
# 3054                      Performance/Voice/Vocal Range   Auto
# 3044        Performance/Ensemble/Ensemble Configuration   Auto
# 3057                    Anatomy/Structure/Dynamic Shape   Auto
# 3053                  Anatomy/Rhythm & Time/Tempo/Speed   Auto
# 3043                            Energy/Emotion/Attitude   Auto
# 3055                  Anatomy/Rhythm & Time/Tempo/Speed   Auto
# 3049                            Energy/Emotion/Positive   Auto
#
#                           taxonomy_node_id             value
# 3042  aebebe3e-ac1f-44e2-a344-692afb387fa6                 C
# 3061  ca8d3fea-e3cc-4c38-abd3-0a32e49a311f            130.54
# 3056  8beb64e1-7287-4f05-b225-f1a31ba4e333                 4
# 3050  600e609b-d06f-46bd-a5e9-40088309315b             Major
# 3059  ada66447-1442-4b2d-afca-4dfc1b66ac32        Percussion
# 3058  ab89b187-246b-42bd-8eac-93bde9ea9a98    Has Percussion
# 3048  137e3494-28f1-44e0-ad02-625abe2d47bf          No Winds
# 3052  7523ec70-c471-47a4-8837-8f1e595cf7e6          No Choir
# 3046  0b1ef0c0-ebbe-46e8-afb6-0b4a3ad6ff21            Steady
# 3063  df112352-99b1-4cda-b46b-6b68d97ed796     Voice & Music
# 3051  64b277d8-6f18-40c3-9d02-7d966012d0cb          Drum Set
# 3062  d064ff52-ad7b-4933-a6e3-4a4001331acc             Light
# 3060  b1eb3b83-adb1-4cd0-93fd-c1fe815ffed4          Electric
# 3045  0045b3a0-e3ce-439a-905b-50ab4e25f578     Low Intensity
# 3047  0d8dbaa8-69d3-4dce-8dd5-993b10fa3a03        No Strings
# 3054  78a59e57-ceb2-4512-b469-d3826ef4d863  High Vocal Range
# 3044  ddb813d8-3410-43ce-8e1a-f2c9b047ff49          Pop Band
# 3057  9db35582-5cb7-45ea-9bc3-1534c1b5bd82           Dynamic
# 3053  76c2f4a0-9e78-4c48-b9bf-4864e9957c3a            Medium
# 3043  5eb43531-159c-44d2-bd75-08a8fa80f2c4       Sentimental
# 3055  81d65be3-1438-43fb-9ca1-82414d1e9930              Slow
# 3049  5c55f7dd-506b-4310-9cfc-fd9242aa884e          Romantic

# %%
isrcs_GBAYE8200083 = df_all[df_all.seed_isrc=='GBAYE8200083'].isrc.unique()

# %%
similar_no_dupl = pd.DataFrame(columns=tags_similar.columns)

for isrc in tags_similar.isrc.unique():
    
    tag_slice = tags[tags.isrc==isrc]

    paths = tag_slice.path.unique()

    dupl = []

    for i, path in enumerate(paths):
        for j, path2 in enumerate(paths):
            if i!=j:
                if path2 in path:
                    dupl.append(path2)
                
    duplicates = list(set(dupl))
    
    slice_no_dupl = tag_slice[~tag_slice.path.isin(duplicates)]
    
    similar_no_dupl = pd.concat([tags_no_dupl,slice_no_dupl], ignore_index=True)

# %%
tags_similar_GBAYE8200083 = similar_no_dupl[similar_no_dupl.isrc.isin(isrcs_GBAYE8200083)]
