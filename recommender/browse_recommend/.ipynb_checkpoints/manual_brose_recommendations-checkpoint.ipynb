# %%
import pandas as pd
import numpy as np
import sys
import pickle

# %%
from pitched_recommend import Recommender

# %%
playlists_data = pd.read_csv('/Users/meshchd/Downloads/recommender_browse_recommendations_playlists_data.csv')
playlists_list = pd.read_csv('/Users/meshchd/Downloads/recommender_browse_recommendations_playlists_list.csv')

# %%
playlists_list.head()
# Out:
#   territory category_id  Position                             playlist_uri  \
# 0        TR         pop         4  spotify:playlist:37i9dQZF1DWXoHqNlfcLJb
# 1        TR         pop         6  spotify:playlist:37i9dQZF1DX9G2MXp8YYmm
# 2        AT         pop         2  spotify:playlist:37i9dQZF1DX2YSAZIuAiB1
# 3        CH         pop        14  spotify:playlist:37i9dQZF1DX2YSAZIuAiB1
# 4        DE         pop         2  spotify:playlist:37i9dQZF1DX2YSAZIuAiB1
#
#   playlist_name
# 0          OLAY
# 1         Lokal
# 2         Swag!
# 3         Swag!
# 4         Swag!

# %%
playlists_data.head()
# Out:
#         playlist_name  listeners country_owner playlist_owner  ranking  \
# 0    Today's Top Hits    4110687            US        spotify        1
# 1           RapCaviar    2679420            US        spotify        1
# 2         Summer Hits    2149595            US        spotify        1
# 3        Mega Hit Mix    1943838            US        spotify        1
# 4  Esquenta Sertanejo    1822133            BR        spotify        1
#
#    pl_ranking                             playlist_uri
# 0           1  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# 1           1  spotify:playlist:37i9dQZF1DX0XUsuxWHRQd
# 2           1  spotify:playlist:37i9dQZF1DX1gRalH1mWrP
# 3           1  spotify:playlist:37i9dQZF1DXbYM3nMM0oPk
# 4           1  spotify:playlist:37i9dQZF1DXdSjVZQzv2tl

# %%
def get_browse_playlists(playlists_data, playlists_list):

    playlists_data['long_uri'] = ['spotify:user:'+str(x) for x in playlists_data.playlist_uri]

    data = playlists_list.merge(playlists_data, how='left', left_on='playlist_uri', right_on='long_uri')

### Get the 'same_as_country' column

    data['same_as_country'] = [1 if x==y else 0 for (x,y) in zip(data.territory,data.country_owner)]

### Get the 'count_appearance' column

    playlist_count = data.playlist_uri_x.value_counts()
    playlist_count = pd.DataFrame(playlist_count).reset_index().rename(columns={'index':'playlist_uri',
                                                                            'playlist_uri_x':'count_appearance'})
    data = data.merge(playlist_count, how='left', left_on = 'playlist_uri_x', right_on = 'playlist_uri')

### Get the 'local' column

    data['local'] = [1 if x<20 else 0 for x in data.count_appearance]

### Get the 'mean_listeners_cat_terr' column

    by_cat_terr = data.groupby(by=['territory','category_id']).listeners.mean()
    df_cat_terr = pd.DataFrame(by_cat_terr).reset_index()
    df_cat_terr = df_cat_terr.rename(columns = {'listeners':'mean_listeners_cat_terr'})

    data = data.merge(df_cat_terr, how='left', left_on = ['territory','category_id'], 
                      right_on = ['territory','category_id'])

### Get the 'popular' column

    data['popular'] = [1 if x>y else 0 for (x,y) in zip(data.listeners,data.mean_listeners_cat_terr)]

### Get the 'score' column with the overall score
    data['score'] = data.same_as_country + data.local + data.popular

    cols = ['territory', 'category_id', 'Position', 'playlist_uri',
       'playlist_name_x', 'listeners', 'country_owner', 'count_appearance',
        'mean_listeners_cat_terr', 'same_as_country', 'local', 'popular',
        'score']


    data = data[cols].sort_values(by=['territory','category_id','score'], ascending=False)
    data_final = pd.DataFrame(data.groupby(by=['territory','category_id']).head(10).reset_index())
    
    return data_final

# %%
playlists = get_browse_playlists(playlists_data,playlists_list)

# %%
playlists.head()
# Out:
#    index territory category_id  Position  \
# 0  63367        UY     workout         2
# 1  64260        UY     workout         1
# 2  62323        UY     workout        11
# 3  62407        UY     workout        13
# 4  62445        UY     workout         7
#
#                               playlist_uri     playlist_name_x  listeners  \
# 0  spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ       Para Entrenar        NaN
# 1  spotify:playlist:37i9dQZF1DX4PvjnQT47nf  Ritmo de Selección        NaN
# 2  spotify:playlist:37i9dQZF1DX4eRPd9frC1m                Hype        NaN
# 3  spotify:playlist:37i9dQZF1DWSJHnPb1f0X3              Cardio        NaN
# 4  spotify:playlist:37i9dQZF1DX70RN3TfWWJh             Workout        NaN
#
#   country_owner  count_appearance  mean_listeners_cat_terr  same_as_country  \
# 0           NaN                17                      NaN                0
# 1           NaN                 6                      NaN                0
# 2           NaN                58                      NaN                0
# 3           NaN                58                      NaN                0
# 4           NaN                58                      NaN                0
#
#    local  popular  score
# 0      1        0      1
# 1      1        0      1
# 2      0        0      0
# 3      0        0      0
# 4      0        0      0

# %%
playlists.shape
# Out:
# (20643, 14)

# %%
with open('/Users/meshchd/Downloads/recommender_model_model_20190504.pkl', 'r+b') as pickle_file:
    model = pickle.load(pickle_file)

# %%
class MacOSFile(object):
    def __init__(self, f):
        self.f = f

    def __getattr__(self, item):
        return getattr(self.f, item)

    def read(self, n):
        if n >= (1 << 31):
            buffer = bytearray(n)
            pos = 0
            while pos < n:
                size = min(n - pos, 1 << 31 - 1)
                chunk = self.f.read(size)
                buffer[pos:pos + size] = chunk
                pos += size
            return buffer
        return self.f.read(n)

# %%
with open('/Users/meshchd/Downloads/recommender_model_model_20190504.pkl', "rb") as fin:
    model = pickle.load(MacOSFile(fin))

# %%
with open('/Users/meshchd/Downloads/recommender_metadata_metadata_dict.pkl', 'rb') as pickle_file:
    metadata = pickle.load(pickle_file)

# %%
all_territories = list(playlists.territory.unique())

# %%
rec = []

# %%
df=playlists.copy()

# %%
for territory in all_territories:
    #print("Producing recommendations for ", territory)
    terr_cat = list(df[df.territory==territory].category_id.unique())
    for category in terr_cat:
        #print("Producing recommendations for category ", category)
        terr_cat_playlists = list(df[(df.territory==territory)&(df.category_id==category)].playlist_uri.unique())
        rec.extend(model.rec_multiple_playlists(terr_cat_playlists, model.playlists_sparse, territory=territory,
                                          category = category, N=150))

# %%
rec
# Out:
# [(68606,
#   1.3339078,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (14004,
#   1.2918768,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (129396,
#   1.2581462,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (182, 1.2472253, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (12364,
#   1.2163659,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (30672,
#   1.2145071,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (163531,
#   1.205905,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (78904,
#   1.2014798,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (59563,
#   1.1951997,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (106091,
#   1.191828,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (68795, 1.190352, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (36533,
#   1.1893079,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (80646,
#   1.1860666,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (85244,
#   1.1855525,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (147793,
#   1.1777534,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (243949,
#   1.176045,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (48091,
#   1.1736698,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (138742,
#   1.1733894,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (38626,
#   1.1662909,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (8789, 1.1658351, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (67262,
#   1.1642168,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (81567,
#   1.1606969,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (4386, 1.1602919, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (8142, 1.1586986, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (328292,
#   1.1563938,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (166476,
#   1.1546335,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (181483,
#   1.1522131,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (159393,
#   1.1520844,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (22064,
#   1.1512002,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (29006,
#   1.1468834,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (21900,
#   1.1466084,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (59729, 1.145314, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (35325,
#   1.1452796,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (105375,
#   1.1452134,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (137789,
#   1.1440291,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (13285,
#   1.1437364,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (108906,
#   1.1429543,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (11640,
#   1.1424928,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (50151,
#   1.1409261,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (71432,
#   1.1404585,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (217459,
#   1.1395822,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (109324,
#   1.1387179,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (586590,
#   1.1381721,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (13414,
#   1.1355472,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (78027,
#   1.1347448,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (3708, 1.1345298, 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW', 'UY', 'workout'),
#  (28953,
#   1.1337316,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (114260,
#   1.1334308,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (52686,
#   1.1324186,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (184987,
#   1.1323702,
#   'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW',
#   'UY',
#   'workout'),
#  (293676,
#   1.1291308,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (1074, 1.1287863, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (180028,
#   1.1259308,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (250552,
#   1.1257862,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (364389,
#   1.1242461,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (65904,
#   1.1232634,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (44246,
#   1.1222286,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (134698,
#   1.1211548,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (27230,
#   1.1133862,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (2531, 1.1123986, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (276956,
#   1.1120386,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (241652,
#   1.1117475,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (18764,
#   1.1115688,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (179490,
#   1.1083963,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (7817, 1.1037927, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (45864,
#   1.1037426,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (266558,
#   1.1036838,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (69808,
#   1.1001179,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (11594,
#   1.0993434,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (1087, 1.0990891, 'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ', 'UY', 'workout'),
#  (50071,
#   1.0988799,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (52480,
#   1.0987965,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (92677,
#   1.0972025,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (33503,
#   1.0955765,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (36225,
#   1.0941684,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (236778,
#   1.0925598,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (192849,
#   1.092023,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (133859,
#   1.0911494,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (113567,
#   1.0902534,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (160512,
#   1.0900884,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (52706,
#   1.0893092,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (52261,
#   1.0852679,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (38785,
#   1.0839155,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (69681,
#   1.0834267,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (32007,
#   1.0829036,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (187061,
#   1.0817213,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (121819,
#   1.0800152,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (4298, 1.0784116, 'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ', 'UY', 'workout'),
#  (1056, 1.0782411, 'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ', 'UY', 'workout'),
#  (5488, 1.0777283, 'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3', 'UY', 'workout'),
#  (1317, 1.0772259, 'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3', 'UY', 'workout'),
#  (734509,
#   1.0770583,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (383, 1.0767739, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (217488,
#   1.0765963,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (11031,
#   1.0760539,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (14349,
#   1.0729251,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (63434,
#   1.0720587,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (176968,
#   1.0714302,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (10680,
#   1.0714135,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (78940,
#   1.0703431,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (61898,
#   1.0684782,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (15342,
#   1.0675405,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (201901,
#   1.0659456,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (52444,
#   1.0659195,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (458930,
#   1.065737,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (40949,
#   1.0646827,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (15254,
#   1.0642912,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (64410,
#   1.0640817,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (46518, 1.064031, 'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3', 'UY', 'workout'),
#  (67941,
#   1.0633368,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (142538,
#   1.0628068,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (43092,
#   1.0627987,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (58107,
#   1.0621351,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (194256,
#   1.0620542,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (8608, 1.0618064, 'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ', 'UY', 'workout'),
#  (32835,
#   1.0616094,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (102874,
#   1.061288,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (15557,
#   1.0606452,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (36184, 1.059546, 'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP', 'UY', 'workout'),
#  (140610,
#   1.0589108,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (155275,
#   1.0587616,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (200006,
#   1.0586338,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (46478,
#   1.0574642,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (105545,
#   1.0572448,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (23532, 1.056905, 'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3', 'UY', 'workout'),
#  (11465,
#   1.0568933,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (53662,
#   1.0567217,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (129344,
#   1.0563252,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (24218, 1.055661, 'spotify:playlist:37i9dQZF1DX35oM5SPECmN', 'UY', 'workout'),
#  (56312,
#   1.0552199,
#   'spotify:playlist:37i9dQZF1DX35oM5SPECmN',
#   'UY',
#   'workout'),
#  (125904,
#   1.0547383,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (51132,
#   1.0543566,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (167975,
#   1.0538207,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (549392,
#   1.0533636,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (458, 1.052835, 'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ', 'UY', 'workout'),
#  (171498,
#   1.0526328,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (116103,
#   1.0525677,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (46418,
#   1.0519528,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (95471,
#   1.0518836,
#   'spotify:playlist:37i9dQZF1DX9ZKyQHcEFXZ',
#   'UY',
#   'workout'),
#  (808092,
#   1.0514456,
#   'spotify:playlist:37i9dQZF1DWUI1rlvkdQnb',
#   'UY',
#   'workout'),
#  (8125, 1.049892, 'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3', 'UY', 'workout'),
#  (270118,
#   1.0485802,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (193930,
#   1.0483351,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (4677, 1.0480697, 'spotify:playlist:37i9dQZF1DX4eRPd9frC1m', 'UY', 'workout'),
#  (68172,
#   1.0477762,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (102539,
#   1.0475659,
#   'spotify:playlist:37i9dQZF1DX4eRPd9frC1m',
#   'UY',
#   'workout'),
#  (53835,
#   1.0474551,
#   'spotify:playlist:37i9dQZF1DWUI1rlvkdQnb',
#   'UY',
#   'workout'),
#  (60345,
#   1.0459509,
#   'spotify:playlist:37i9dQZF1DWSJHnPb1f0X3',
#   'UY',
#   'workout'),
#  (243682,
#   1.0455785,
#   'spotify:playlist:37i9dQZF1DWUI1rlvkdQnb',
#   'UY',
#   'workout'),
#  (133041,
#   1.0451509,
#   'spotify:playlist:37i9dQZF1DX76Wlfdnj7AP',
#   'UY',
#   'workout'),
#  (253075, 1.236089, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (283352,
#   1.2292824,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (148064,
#   1.2141588,
#   'spotify:playlist:37i9dQZF1DX1mdFJSflVUV',
#   'UY',
#   'travel'),
#  (194671,
#   1.2066953,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (487763,
#   1.1991668,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (259733,
#   1.1976153,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (873344,
#   1.1951686,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (42247, 1.1931005, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (419399,
#   1.1889329,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (849477,
#   1.1769065,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (81534, 1.1736294, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (1074, 1.1699758, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (11581, 1.1683987, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (2347, 1.1675375, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (1572229,
#   1.166992,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (71111, 1.1650455, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (87338, 1.1636262, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (793125,
#   1.1602396,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (92532, 1.1593592, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (11272, 1.1591645, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (2239, 1.1565075, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (11466, 1.1534581, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (34544, 1.1474919, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (1020490,
#   1.1448064,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (119818,
#   1.1422641,
#   'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I',
#   'UY',
#   'travel'),
#  (732131,
#   1.1381639,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (34354, 1.1340513, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (118774,
#   1.1323423,
#   'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I',
#   'UY',
#   'travel'),
#  (1823714,
#   1.1314201,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (182, 1.1279466, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (61821, 1.1277966, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (88397, 1.1270608, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (47529, 1.1258504, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (136385,
#   1.1243458,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (250575,
#   1.1223617,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (23887, 1.1216372, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (55403, 1.1199203, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (26841, 1.1185901, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (48105, 1.1185654, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (17750, 1.1141499, 'spotify:playlist:37i9dQZF1DWTz2CbxASWRu', 'UY', 'travel'),
#  (1062, 1.1137216, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (41535, 1.1131322, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (497050,
#   1.1108823,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (12267, 1.1107984, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (556111,
#   1.1106983,
#   'spotify:playlist:37i9dQZF1DWTz2CbxASWRu',
#   'UY',
#   'travel'),
#  (82769, 1.1087254, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (12743, 1.1077738, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (21291, 1.1076305, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (54820, 1.1070069, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (6438, 1.104885, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (7438, 1.104207, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (5132, 1.1027365, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (315, 1.1013746, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (17481, 1.1013025, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (12135, 1.100826, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (12023, 1.1005409, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (8822, 1.100172, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (160111,
#   1.0986192,
#   'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I',
#   'UY',
#   'travel'),
#  (21316, 1.0969422, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (106031,
#   1.0966833,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (1467, 1.093219, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (19294, 1.0923133, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (10470, 1.0920262, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (44232, 1.091315, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (10555, 1.0911802, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (37102, 1.0909219, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (24567, 1.0901304, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (191799,
#   1.0877914,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (228931, 1.087198, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (5523, 1.0869505, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (7721, 1.0857837, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (139388,
#   1.0852793,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (15463, 1.0839198, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (35765, 1.0827024, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (250053,
#   1.0825158,
#   'spotify:playlist:37i9dQZF1DXdcAnM28dnna',
#   'UY',
#   'travel'),
#  (7360, 1.0811124, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (6255, 1.0790837, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (23903, 1.0786436, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (81223, 1.0778825, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (89087, 1.0773308, 'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B', 'UY', 'travel'),
#  (9940, 1.0764601, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (65789, 1.0745171, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (110287,
#   1.0742368,
#   'spotify:playlist:37i9dQZF1DXdcAnM28dnna',
#   'UY',
#   'travel'),
#  (10401, 1.0739115, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (89312, 1.073862, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (3830, 1.0732462, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (101236, 1.072743, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (13239, 1.072727, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (58083, 1.0722001, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (28301, 1.0715227, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (16692, 1.0705137, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (47056, 1.0702302, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (6174, 1.0701562, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (29410, 1.0694634, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (60099, 1.068022, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (442380,
#   1.0677917,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (7928, 1.0667622, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (215447,
#   1.0667107,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (61355, 1.0661385, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (925993,
#   1.0660362,
#   'spotify:playlist:37i9dQZF1DXdcAnM28dnna',
#   'UY',
#   'travel'),
#  (2602, 1.0657413, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (10743, 1.0649989, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (20229, 1.0647643, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (101818,
#   1.0645747,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (137507,
#   1.0639935,
#   'spotify:playlist:37i9dQZF1DWU13kKnk03AP',
#   'UY',
#   'travel'),
#  (122757,
#   1.0637243,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (530788,
#   1.0634248,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (124720,
#   1.0631983,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (45673, 1.0626518, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (19992, 1.0622835, 'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B', 'UY', 'travel'),
#  (136772,
#   1.0613985,
#   'spotify:playlist:37i9dQZF1DWUFmyho2wkQU',
#   'UY',
#   'travel'),
#  (69269, 1.0613427, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (55597, 1.0611597, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (6788, 1.060983, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (143523,
#   1.0608693,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (11273, 1.0604324, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (1988, 1.0602622, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (22865, 1.0594304, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (14997, 1.0588982, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (34941, 1.0583299, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (22255, 1.0582445, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (69978, 1.0580747, 'spotify:playlist:37i9dQZF1DWUFmyho2wkQU', 'UY', 'travel'),
#  (21922, 1.0578182, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (97601, 1.0577402, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (28978, 1.0574985, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (15707, 1.0573664, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (11407, 1.0573509, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (21519, 1.0573015, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (1334, 1.0568143, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (281091,
#   1.0563353,
#   'spotify:playlist:37i9dQZF1DWUFmyho2wkQU',
#   'UY',
#   'travel'),
#  (24904, 1.0557804, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (32188, 1.0556072, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (131207,
#   1.0553005,
#   'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru',
#   'UY',
#   'travel'),
#  (105815,
#   1.0552473,
#   'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I',
#   'UY',
#   'travel'),
#  (3587, 1.0551891, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (55307, 1.0548054, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (3144, 1.0547779, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (15587, 1.0546975, 'spotify:playlist:37i9dQZF1DX5Ufz5ldo0J4', 'UY', 'travel'),
#  (365597,
#   1.0545349,
#   'spotify:playlist:37i9dQZF1DWUFmyho2wkQU',
#   'UY',
#   'travel'),
#  (24005, 1.0540179, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (57721, 1.0539378, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (28572, 1.0538071, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (17439, 1.0536425, 'spotify:playlist:37i9dQZF1DX1mdFJSflVUV', 'UY', 'travel'),
#  (41398, 1.0535817, 'spotify:playlist:37i9dQZF1DWWiDhnQ2IIru', 'UY', 'travel'),
#  (28136, 1.0530057, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (2324, 1.0517744, 'spotify:playlist:37i9dQZF1DXe3a8ZI7Co8I', 'UY', 'travel'),
#  (150407,
#   1.0516369,
#   'spotify:playlist:37i9dQZF1DWU13kKnk03AP',
#   'UY',
#   'travel'),
#  (613573,
#   1.0510879,
#   'spotify:playlist:37i9dQZF1DX8XxBtyUnC7B',
#   'UY',
#   'travel'),
#  (22882, 1.050715, 'spotify:playlist:37i9dQZF1DWU13kKnk03AP', 'UY', 'travel'),
#  (671938, 1.050488, 'spotify:playlist:37i9dQZF1DX5Ufz5ldo0J4', 'UY', 'travel'),
#  (199253,
#   1.2380426,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (10421,
#   1.2291622,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (106248,
#   1.2125652,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (22118,
#   1.2041423,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (126040,
#   1.1654621,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (2368941,
#   1.163023,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (192957,
#   1.158527,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (802610,
#   1.1576006,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (45070,
#   1.1533804,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (1988523,
#   1.1526628,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (279867,
#   1.1522379,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (1773919,
#   1.1488564,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (104644,
#   1.1486948,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (1251641,
#   1.14527,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (33049,
#   1.1368085,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (262955,
#   1.133568,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (526086,
#   1.1334327,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (476827,
#   1.127588,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (736625,
#   1.125351,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (48154,
#   1.1240536,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (182, 1.1232983, 'spotify:playlist:37i9dQZF1DWV8ttjhONFA1', 'UY', 'toplists'),
#  (433652,
#   1.1219761,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (785, 1.1182964, 'spotify:playlist:37i9dQZF1DX8O2z77nfMgH', 'UY', 'toplists'),
#  (18275,
#   1.1177694,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (44890,
#   1.1176162,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (894927,
#   1.1175582,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (649301,
#   1.1169298,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (1172955,
#   1.1165179,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (1294162,
#   1.1164789,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (694304,
#   1.1154218,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (351287,
#   1.1126829,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (576155,
#   1.1101904,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (120846,
#   1.1096545,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (579230,
#   1.1091998,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (599737,
#   1.109185,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (450208,
#   1.1087625,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (283323,
#   1.1073298,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (835990,
#   1.1060228,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (271885,
#   1.1055249,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (28572,
#   1.1053592,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (198728,
#   1.1053305,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (181069,
#   1.1037782,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (261222,
#   1.1031542,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (73188,
#   1.1021265,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (186169,
#   1.1007558,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (803731,
#   1.0982878,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (23715,
#   1.0969119,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (640920,
#   1.0965228,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (4707, 1.096114, 'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw', 'UY', 'toplists'),
#  (600702,
#   1.093833,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (214464,
#   1.093681,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (179021,
#   1.0930814,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (205898,
#   1.0926208,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (389276,
#   1.0921649,
#   'spotify:playlist:37i9dQZF1DX8O2z77nfMgH',
#   'UY',
#   'toplists'),
#  (15568,
#   1.0869577,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (89480,
#   1.0867538,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (353715,
#   1.0840459,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (408649,
#   1.0820125,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (16548,
#   1.0807579,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (7428,
#   1.0793271,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (1689701,
#   1.0787622,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (1931, 1.077023, 'spotify:playlist:37i9dQZF1DX92MLsP3K1fI', 'UY', 'toplists'),
#  (312956,
#   1.0761383,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (1063197,
#   1.0734334,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (309854,
#   1.0732901,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (26881,
#   1.0732265,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (452457,
#   1.0731183,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (53374,
#   1.0727651,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (10576,
#   1.0702378,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (29374,
#   1.0697974,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (703365,
#   1.0691981,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (3199799,
#   1.0680373,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (700264,
#   1.0677588,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (48987,
#   1.0672371,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (160155, 1.0659, 'spotify:playlist:37i9dQZF1DX92MLsP3K1fI', 'UY', 'toplists'),
#  (111531,
#   1.0649323,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (25821,
#   1.0646402,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (10743,
#   1.0640609,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (1606982,
#   1.062787,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (981757,
#   1.0623863,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (289924,
#   1.0613201,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (695801,
#   1.0609202,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (65562,
#   1.060521,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (49647,
#   1.0599674,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (764775,
#   1.0597157,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (140149,
#   1.0592854,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (371289,
#   1.058432,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (31694,
#   1.0582168,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (26103,
#   1.0578661,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (72009,
#   1.0567806,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (135018,
#   1.056577,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (322742,
#   1.0565355,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (18950,
#   1.0560734,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (64444,
#   1.0559744,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (39699,
#   1.0550925,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (35347,
#   1.0545872,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (260969,
#   1.05446,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (778515,
#   1.0527791,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (617434,
#   1.0524836,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (645581,
#   1.0520742,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (5559,
#   1.0511415,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (10787,
#   1.0506923,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (915971,
#   1.0488876,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (611448,
#   1.0486586,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (361583,
#   1.0486257,
#   'spotify:playlist:37i9dQZF1DWV8ttjhONFA1',
#   'UY',
#   'toplists'),
#  (478047,
#   1.0484651,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (1662627,
#   1.0479314,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (2092,
#   1.0470978,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (6383,
#   1.0466479,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (342243,
#   1.0466108,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (40890,
#   1.0458682,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (30591,
#   1.0449512,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (89332,
#   1.0444416,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (387366,
#   1.044395,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (622663,
#   1.0441346,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (4436,
#   1.0436532,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (6193,
#   1.0435154,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (108020,
#   1.043506,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (140478,
#   1.0432074,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (1200310,
#   1.0428743,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (424270,
#   1.0427012,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (107476,
#   1.0424955,
#   'spotify:playlist:37i9dQZF1DWZU5DGR2xCSH',
#   'UY',
#   'toplists'),
#  (67532,
#   1.0423024,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (61217,
#   1.0421898,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (169375,
#   1.0406808,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (111333,
#   1.040379,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (447507,
#   1.0399265,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (70839,
#   1.0398968,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (20339,
#   1.0397776,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (761887,
#   1.039615,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (136597,
#   1.0394403,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (71435,
#   1.039382,
#   'spotify:playlist:37i9dQZF1DX7kV7MLy24Ug',
#   'UY',
#   'toplists'),
#  (55929,
#   1.038364,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (65903, 1.03815, 'spotify:playlist:37i9dQZF1DX92MLsP3K1fI', 'UY', 'toplists'),
#  (11158,
#   1.0380751,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (61190,
#   1.0378731,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (23470,
#   1.0374078,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (15040,
#   1.0371606,
#   'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv',
#   'UY',
#   'toplists'),
#  (708602,
#   1.0371494,
#   'spotify:playlist:37i9dQZF1DWU6aakG7fctq',
#   'UY',
#   'toplists'),
#  (47056,
#   1.0370865,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (268821,
#   1.0366523,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (178529,
#   1.0366366,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (54508,
#   1.0364335,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (22067,
#   1.0363197,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (151875,
#   1.0362989,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (9368,
#   1.0362723,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (2965,
#   1.0361563,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (45030,
#   1.0355828,
#   'spotify:playlist:37i9dQZF1DX92MLsP3K1fI',
#   'UY',
#   'toplists'),
#  (31996,
#   1.0345314,
#   'spotify:playlist:37i9dQZF1DX5y71ufjoyXC',
#   'UY',
#   'toplists'),
#  (162213,
#   1.0344576,
#   'spotify:playlist:37i9dQZF1DX8DBcbHcgPJw',
#   'UY',
#   'toplists'),
#  (188651,
#   1.3228735,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (29939, 1.2980402, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (6449, 1.2650807, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (68507, 1.2624996, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (170385, 1.259719, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (5716, 1.2451749, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (56691, 1.2107767, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (2599, 1.2075303, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (16827, 1.2067919, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (125726,
#   1.2005527,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (112592,
#   1.1988628,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (83000, 1.1973084, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (17673, 1.1873984, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (14956, 1.184849, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (23864, 1.1788031, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (182, 1.1734484, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (14997, 1.1716422, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (1728, 1.1710389, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (116153, 1.167249, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (2997, 1.1586899, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (46733, 1.1586367, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (5488, 1.1572225, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (12074, 1.1556344, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (3376, 1.1502848, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (5454, 1.1489522, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (45647, 1.1413177, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (59220, 1.1405668, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (248438,
#   1.1402342,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (175119,
#   1.1392455,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (48631, 1.1391236, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (110927,
#   1.1390802,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (2381, 1.1370337, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (135358,
#   1.1341543,
#   'spotify:playlist:37i9dQZF1DXb3m918yXHxA',
#   'UY',
#   'summer'),
#  (7697, 1.133316, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (19894, 1.1326227, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (137260,
#   1.1323156,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (103240,
#   1.1322408,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (14677, 1.1311094, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (56461, 1.1307069, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (10760, 1.1298759, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (31797, 1.1289492, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (51027, 1.1280863, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (230069, 1.127579, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (95165, 1.1273354, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (145124,
#   1.1263467,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (37834, 1.1256187, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (109955,
#   1.1237724,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (106733,
#   1.1217726,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (10886, 1.1195102, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (70039, 1.1193988, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (283605,
#   1.1187973,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (282335,
#   1.1169206,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (100809,
#   1.1151309,
#   'spotify:playlist:37i9dQZF1DXb3m918yXHxA',
#   'UY',
#   'summer'),
#  (17253, 1.111799, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (201308,
#   1.1106021,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (81686, 1.1100261, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (19240, 1.1094141, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (454506,
#   1.1086178,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (35206, 1.1083257, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (74631, 1.108154, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (133419,
#   1.1060399,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (590635,
#   1.1056037,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (78940, 1.1052921, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (2015, 1.1046624, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (136836,
#   1.1028522,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (43680, 1.1027901, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (51990, 1.1011307, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (37053, 1.1003075, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (211809,
#   1.0997274,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (178402,
#   1.0989605,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (96253, 1.0988576, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (202766,
#   1.0961426,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (169384,
#   1.0958612,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (216224,
#   1.0935457,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (51917, 1.0929633, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (11545, 1.0928601, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (209263,
#   1.0924494,
#   'spotify:playlist:37i9dQZF1DXb3m918yXHxA',
#   'UY',
#   'summer'),
#  (230713, 1.091319, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (106982,
#   1.0911667,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (49554, 1.089221, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (115574,
#   1.0890689,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (246438,
#   1.0888746,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (7731, 1.0885649, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (55694, 1.0885537, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (82769, 1.0878046, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (337807,
#   1.0876722,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (36093, 1.0870533, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (78951, 1.086828, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (4634, 1.0862677, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (13047, 1.0857867, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (48887, 1.0857732, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (177952,
#   1.0857444,
#   'spotify:playlist:37i9dQZF1DXb3m918yXHxA',
#   'UY',
#   'summer'),
#  (72074, 1.0853599, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (30701, 1.0852802, 'spotify:playlist:37i9dQZF1DWSf2RDTDayIx', 'UY', 'summer'),
#  (132629,
#   1.0847957,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (10890, 1.0841992, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (214629,
#   1.0841265,
#   'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR',
#   'UY',
#   'summer'),
#  (7990, 1.0838945, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (320, 1.08376, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (9216, 1.0833498, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (57719, 1.0826995, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (63979, 1.0823952, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
#  (64362, 1.0820525, 'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ', 'UY', 'summer'),
#  (274, 1.0819447, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (227286,
#   1.0808433,
#   'spotify:playlist:37i9dQZF1DWSf2RDTDayIx',
#   'UY',
#   'summer'),
#  (143923,
#   1.0805194,
#   'spotify:playlist:37i9dQZF1DWVAArCxuIRGQ',
#   'UY',
#   'summer'),
#  (6209, 1.0799756, 'spotify:playlist:37i9dQZF1DWZKxDdpAkEjR', 'UY', 'summer'),
#  (57363, 1.0796802, 'spotify:playlist:37i9dQZF1DXb3m918yXHxA', 'UY', 'summer'),
# ...
#   'UY',
#   'sleep'),
#  (861576, 1.0250988, 'spotify:playlist:37i9dQZF1DWSUFOo47GEsI', 'UY', 'sleep'),
#  (30207, 1.0249954, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (1379135,
#   1.0237825,
#   'spotify:playlist:37i9dQZF1DWSUFOo47GEsI',
#   'UY',
#   'sleep'),
#  (241740, 1.0237601, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (1033875,
#   1.0236282,
#   'spotify:playlist:37i9dQZF1DWSUFOo47GEsI',
#   'UY',
#   'sleep'),
#  (71183, 1.0235475, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (1493193,
#   1.0233252,
#   'spotify:playlist:37i9dQZF1DWSUFOo47GEsI',
#   'UY',
#   'sleep'),
#  (1284386,
#   1.0233033,
#   'spotify:playlist:37i9dQZF1DWSUFOo47GEsI',
#   'UY',
#   'sleep'),
#  (162296, 1.0228046, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (964257, 1.022369, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (224755, 1.0221741, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (53466, 1.0219481, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (39723, 1.0218146, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (535499, 1.021764, 'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd', 'UY', 'sleep'),
#  (87889, 1.021435, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (1112285,
#   1.0213734,
#   'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3',
#   'UY',
#   'sleep'),
#  (545319, 1.0213153, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (572982, 1.0212858, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (300393, 1.0210876, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (149331, 1.0209386, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (267083, 1.0207433, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (102821, 1.0203204, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (730011, 1.0196129, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (1632087,
#   1.0194057,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (918487, 1.0193337, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (557739, 1.0190849, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (1539134,
#   1.0186954,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (35306, 1.0182722, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (161539, 1.0176666, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (2178, 1.017106, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (693947, 1.0169337, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (65685, 1.016763, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (2137289,
#   1.0166419,
#   'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3',
#   'UY',
#   'sleep'),
#  (1649552, 1.016228, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (21156, 1.0161221, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (291418, 1.0159402, 'spotify:playlist:37i9dQZF1DWZd79rJ6a7lp', 'UY', 'sleep'),
#  (130801, 1.0159127, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (463789, 1.0157336, 'spotify:playlist:37i9dQZF1DX1SGz4XfZKy2', 'UY', 'sleep'),
#  (16542, 1.0150758, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (646586, 1.0146506, 'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd', 'UY', 'sleep'),
#  (354984, 1.0143833, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (410226, 1.0131834, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (424014, 1.0120448, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (174614, 1.010775, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (18565, 1.0105062, 'spotify:playlist:37i9dQZF1DX1SGz4XfZKy2', 'UY', 'sleep'),
#  (1123906,
#   1.0104637,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (53835, 1.0096481, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (920748, 1.009479, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (389344, 1.009399, 'spotify:playlist:37i9dQZF1DWTmhGAhbrFb3', 'UY', 'sleep'),
#  (658992, 1.0091357, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (1353, 1.0089247, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (659545, 1.0087309, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (407430, 1.008328, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (735337, 1.0082021, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (226752, 1.0079142, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (524889, 1.0049024, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (750508, 1.0040767, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (682592, 1.0040327, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (667111, 1.0037644, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (104400, 1.002972, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (155358, 0.9999707, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (322160,
#   0.99992275,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (829169,
#   0.99984723,
#   'spotify:playlist:37i9dQZF1DX1SGz4XfZKy2',
#   'UY',
#   'sleep'),
#  (160578,
#   0.99904567,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (683680, 0.9989991, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (97720, 0.9983307, 'spotify:playlist:37i9dQZF1DWYb5LrMR5V59', 'UY', 'sleep'),
#  (2157049,
#   0.9979229,
#   'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj',
#   'UY',
#   'sleep'),
#  (449884, 0.9968754, 'spotify:playlist:37i9dQZF1DWXsneKPbmjeu', 'UY', 'sleep'),
#  (827514,
#   0.99669945,
#   'spotify:playlist:37i9dQZF1DWZhzMp90Opmn',
#   'UY',
#   'sleep'),
#  (723901,
#   0.99551046,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (451, 0.9944172, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (964493, 0.9941994, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (396118,
#   0.99326336,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (598875,
#   0.99313766,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (1196920,
#   0.9929671,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (819698,
#   0.99276865,
#   'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj',
#   'UY',
#   'sleep'),
#  (2871, 0.99245095, 'spotify:playlist:37i9dQZF1DWXsneKPbmjeu', 'UY', 'sleep'),
#  (233710,
#   0.99213606,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (18385, 0.9914303, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (156055, 0.9910977, 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj', 'UY', 'sleep'),
#  (236771, 0.9910782, 'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd', 'UY', 'sleep'),
#  (1461975,
#   0.9905268,
#   'spotify:playlist:37i9dQZF1DXbcPC6Vvqudd',
#   'UY',
#   'sleep'),
#  (1514583,
#   0.99050456,
#   'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj',
#   'UY',
#   'sleep'),
#  (1483173,
#   0.9903382,
#   'spotify:playlist:37i9dQZF1DWYb5LrMR5V59',
#   'UY',
#   'sleep'),
#  (135051,
#   1.2461891,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (179139,
#   1.2313051,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (455709,
#   1.2175958,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (75339,
#   1.195888,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (67700,
#   1.1749678,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (502040,
#   1.1560433,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (387979,
#   1.1456761,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (154422,
#   1.1450437,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (66040,
#   1.1415114,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (49066,
#   1.1334244,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (361592,
#   1.1254804,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (577734,
#   1.1224041,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (80698,
#   1.1218255,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (685850,
#   1.1194501,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (68806,
#   1.1175114,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (41931,
#   1.1159085,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (33809,
#   1.1143695,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (467009,
#   1.1127754,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (35858,
#   1.1088617,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (275807,
#   1.1069579,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (17755,
#   1.1050255,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (170624,
#   1.1035211,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (97356,
#   1.1031935,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (1940438,
#   1.1009624,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (281967,
#   1.0990944,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (266485,
#   1.0989332,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (712100,
#   1.09622,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (180988,
#   1.0918293,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (26010,
#   1.091049,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (84684,
#   1.0909191,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (973296,
#   1.0905914,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (489972,
#   1.0878716,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (322994,
#   1.0865811,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (276693,
#   1.0852017,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (475853,
#   1.084559,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (649508,
#   1.0839784,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (235378,
#   1.0833311,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (108578,
#   1.0826613,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (184410,
#   1.0805471,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (437571,
#   1.0759113,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (126543,
#   1.0752766,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (367554,
#   1.0749145,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (4363,
#   1.0707664,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (898419,
#   1.0691673,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (418242,
#   1.0688188,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (21244,
#   1.0681581,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (613295,
#   1.0657145,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (1399817,
#   1.0636072,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (641918,
#   1.0630805,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (120245,
#   1.0630405,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (119071,
#   1.0623612,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (375202,
#   1.0606596,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (581407,
#   1.0593785,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (99219,
#   1.0588682,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (581205,
#   1.0587392,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (1034767,
#   1.058692,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (150767,
#   1.0586157,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (330777,
#   1.0584178,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (335511,
#   1.0583826,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (88967,
#   1.0577494,
#   'spotify:playlist:37i9dQZF1DWTUm9HjVUKnL',
#   'UY',
#   'sessions'),
#  (453205,
#   1.0573245,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (169380,
#   1.0567589,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (252868,
#   1.0559473,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (766170,
#   1.0557382,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (238284,
#   1.0550395,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (196513,
#   1.0541704,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (158605,
#   1.0533917,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (107264,
#   1.05126,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (240431,
#   1.0510008,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (734672,
#   1.05003,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (1575749,
#   1.0498694,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (209041,
#   1.0482234,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (60635,
#   1.0480626,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (499028,
#   1.0476904,
#   'spotify:playlist:37i9dQZF1DWZqyWCBK6QTt',
#   'UY',
#   'sessions'),
#  (53475,
#   1.0443876,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (821723,
#   1.043847,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (844805,
#   1.0431368,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (109854,
#   1.0428996,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (602736,
#   1.0414319,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (371601,
#   1.0405619,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (366818,
#   1.0390913,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (396786,
#   1.0368261,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (24482,
#   1.0334746,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (373302,
#   1.0321068,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (300629,
#   1.0303361,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (494190,
#   1.0296566,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (39525,
#   1.0294492,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (14530,
#   1.0293853,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (52339,
#   1.0282056,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (508563,
#   1.0278227,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (1403029,
#   1.0269091,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (544664,
#   1.0215452,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (826716,
#   1.0211426,
#   'spotify:playlist:37i9dQZF1DXdFhiq9L31be',
#   'UY',
#   'sessions'),
#  (423579,
#   1.0185597,
#   'spotify:playlist:37i9dQZF1DWXMetQrUYhar',
#   'UY',
#   'sessions'),
#  (41075,
#   1.0184901,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (140285,
#   1.018244,
#   'spotify:playlist:37i9dQZF1DXdXh4ecan7Hh',
#   'UY',
#   'sessions'),
#  (604222,
#   1.0179472,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (12496,
#   1.0177659,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (48714,
#   1.0163014,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  (68375,
#   1.0156922,
#   'spotify:playlist:37i9dQZF1DWVP71DYelp29',
#   'UY',
#   'sessions'),
#  ...]

# %%
for territory in all_territories:
    #print("Producing recommendations for ", territory)
    terr_cat = list(df[df.territory==territory].category_id.unique())
    for category in terr_cat:
        #print("Producing recommendations for category ", category)
        terr_cat_playlists = list(df[(df.territory==territory)&(df.category_id==category)].playlist_uri.unique())
        rec.extend(model.rec_multiple_playlists(terr_cat_playlists, model.playlists_sparse, territory=territory,
                                          category = category, N=150))

recommendations = [(model.isrcs[x[0]],float(x[1]),x[2],x[3],x[4]) for x in rec]
recs_final = [(x[0],x[1],metadata['track_artist'][x[0]], metadata['track_title'][x[0]], metadata['major_label'][x[0]], metadata['label_studio'][x[0]],
               metadata['original_release_date'][x[0]], metadata['genre_name'][x[0]], metadata['parent_genre_name'][x[0]], 
               x[2], x[3], x[4]) for x in list(recommendations)]

all_columns = ['isrc','score','artist','title','major_label','label_studio','original_release_date','genre_name',
               'parent_genre_name','seed_playlist_uri','territory','category']
rec_df = pd.DataFrame(recs_final, columns = all_columns)
rec_df_umg = rec_df[rec_df.major_label=='UMG']

final_columns = ['territory', 'category', 'score', 'isrc', 'seed_playlist_uri', 'artist', 'title', 'original_release_date']
rec_df_final = rec_df_umg[final_columns]

rec_df_final.to_csv('~/Downloads/manual_recommendations_20190408.csv', index=False, sep='\t')

# %%
recommendations = [(model.isrcs[x[0]],float(x[1]),x[2],x[3],x[4]) for x in rec]
recs_final = [(x[0],x[1],metadata['track_artist'][x[0]], metadata['track_title'][x[0]], metadata['major_label'][x[0]], metadata['label_studio'][x[0]],
               metadata['original_release_date'][x[0]], metadata['genre_name'][x[0]], metadata['parent_genre_name'][x[0]], 
               x[2], x[3], x[4]) for x in list(recommendations)]

all_columns = ['isrc','score','artist','title','major_label','label_studio','original_release_date','genre_name',
               'parent_genre_name','seed_playlist_uri','territory','category']
rec_df = pd.DataFrame(recs_final, columns = all_columns)
rec_df_umg = rec_df[rec_df.major_label=='UMG']

final_columns = ['territory', 'category', 'score', 'isrc', 'seed_playlist_uri', 'artist', 'title', 'original_release_date']
rec_df_final = rec_df_umg[final_columns]

rec_df_final.to_csv('~/Downloads/manual_recommendations_20190614.csv', index=False, sep='\t')

# %%
rec_df_final.head()
# Out:
#    territory category     score          isrc  \
# 0         UY  workout  1.333908  USC4R1503363
# 2         UY  workout  1.258146  QZ4JX1760724
# 7         UY  workout  1.201480  USUM71801625
# 10        UY  workout  1.190352  QMJMT1300027
# 14        UY  workout  1.177753  QZ4JX1760824
#
#                           seed_playlist_uri  \
# 0   spotify:playlist:37i9dQZF1DX35oM5SPECmN
# 2   spotify:playlist:37i9dQZF1DWTl4y3vgJOXW
# 7   spotify:playlist:37i9dQZF1DWTl4y3vgJOXW
# 10  spotify:playlist:37i9dQZF1DWTl4y3vgJOXW
# 14  spotify:playlist:37i9dQZF1DWTl4y3vgJOXW
#
#                                    artist            title  \
# 0   Nathaniel Rateliff & The Night Sweats           S.O.B.
# 2                                Lil Baby          My Dawg
# 7                                2 Chainz            PROUD
# 10                                  JAY Z         Tom Ford
# 14                               Lil Baby  All Of A Sudden
#
#    original_release_date
# 0             2015-06-16
# 2             2017-07-18
# 7             2018-03-23
# 10            2013-01-01
# 14            2017-12-01

# %%
rec_df_final[rec_df_final.title=='Unknown']
# Out:
# Empty DataFrame
# Columns: [territory, category, score, isrc, seed_playlist_uri, artist, title, original_release_date]
# Index: []

# %%
playlists[(playlists.territory=='DE')&(playlists.category_id=='rock')]
# Out:
#        index territory category_id  Position  \
# 15020  19924        DE        rock         1
# 15021  20092        DE        rock        24
# 15022  21094        DE        rock        11
# 15023  22593        DE        rock        37
# 15024  19247        DE        rock        35
# 15025  19264        DE        rock         2
# 15026  19342        DE        rock        41
# 15027  19443        DE        rock        10
# 15028  19520        DE        rock         9
# 15029  19583        DE        rock         8
#
#                                   playlist_uri         playlist_name_x  \
# 15020  spotify:playlist:37i9dQZF1DX4vth7idTQch              Rockhymnen
# 15021  spotify:playlist:37i9dQZF1DX7fE85waV8CI             Klare Kante
# 15022  spotify:playlist:37i9dQZF1DWZJhOVGWqUKF           Rock Rotation
# 15023  spotify:playlist:37i9dQZF1DXbz5uvvU2C9n  Alternative Generation
# 15024  spotify:playlist:37i9dQZF1DX1X7WV84927n               Hard Rock
# 15025  spotify:playlist:37i9dQZF1DWWGFQLoP9qlv               Legendary
# 15026  spotify:playlist:37i9dQZF1DWT2jS7NwYPVI               New Noise
# 15027  spotify:playlist:37i9dQZF1DWWJOmJ7nRx0C               Rock Hard
# 15028  spotify:playlist:37i9dQZF1DXcF6B6QPhFDv               Rock This
# 15029  spotify:playlist:37i9dQZF1DX6xOPeSOGone               Soft Rock
#
#        listeners country_owner  count_appearance  mean_listeners_cat_terr  \
# 15020        NaN           NaN                 3                      NaN
# 15021        NaN           NaN                 3                      NaN
# 15022        NaN           NaN                 3                      NaN
# 15023        NaN           NaN                 4                      NaN
# 15024        NaN           NaN               113                      NaN
# 15025        NaN           NaN                58                      NaN
# 15026        NaN           NaN                58                      NaN
# 15027        NaN           NaN                72                      NaN
# 15028        NaN           NaN                89                      NaN
# 15029        NaN           NaN                58                      NaN
#
#        same_as_country  local  popular  score
# 15020                0      1        0      1
# 15021                0      1        0      1
# 15022                0      1        0      1
# 15023                0      1        0      1
# 15024                0      0        0      0
# 15025                0      0        0      0
# 15026                0      0        0      0
# 15027                0      0        0      0
# 15028                0      0        0      0
# 15029                0      0        0      0
