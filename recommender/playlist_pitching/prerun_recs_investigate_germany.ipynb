# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/daria/Downloads/recommender_browse_recommendations_browse_recommendations_20190314.csv', delimiter='\t')

# %%
data.head()
# Out:
#   territory category     score          isrc  \
# 0        UY  workout  1.468299  GBUM71101222
# 1        UY  workout  1.467567  USUM71001801
# 2        UY  workout  1.406886  USUM71209505
# 3        UY  workout  1.372845  USUM71800022
# 4        UY  workout  1.346207  USUM71318551
#
#                                    seed_playlist_uri       artist  \
# 0  spotify:user:spotify:playlist:37i9dQZF1DXadOVC...   Alex Clare
# 1  spotify:user:spotify:playlist:37i9dQZF1DXadOVC...   Neon Trees
# 2  spotify:user:spotify:playlist:37i9dQZF1DXadOVC...  OneRepublic
# 3  spotify:user:spotify:playlist:37i9dQZF1DWUVpAX...       Eminem
# 4  spotify:user:spotify:playlist:37i9dQZF1DXadOVC...  MisterWives
#
#                                               title original_release_date
# 0                                         Too Close   2012-01-01 00:00:00
# 1                                            Animal   2010-01-01 00:00:00
# ...

# %%
germany = data[data.territory=='DE']

# %%
germany[germany.category=='pop']
# Out:
#       territory category     score          isrc  \
# 59566        DE      pop  1.327545  USUM71616407
# 59567        DE      pop  1.291006  USUM71708227
# 59568        DE      pop  1.271596  DEVP21600001
# 59569        DE      pop  1.268772  GBAAA1200935
# 59570        DE      pop  1.256470  USUM71705365
# 59571        DE      pop  1.233342  DEVQ71600001
# 59572        DE      pop  1.221022  USUG11702132
# 59573        DE      pop  1.187567  USAT21704316
# 59574        DE      pop  1.187519  USUM71709292
# 59575        DE      pop  1.186036  NZUM71700074
# 59576        DE      pop  1.179719  SE5R71700101
# 59577        DE      pop  1.165132  DEUM71725106
# 59578        DE      pop  1.162712  DEUM71723675
# 59579        DE      pop  1.160716  DEUM71503730
# 59580        DE      pop  1.157990  USUM71704121
# 59581        DE      pop  1.157077  GBUM71705147
# 59582        DE      pop  1.151500  USUM71805992
# 59583        DE      pop  1.148553  USUM71701083
# ...

# %%
germany[germany.category=='pop'].seed_playlist_uri.unique()
# Out:
# array(['spotify:user:spotify:playlist:37i9dQZF1DX8ttEdg9VJHO',
#        'spotify:user:spotify:playlist:37i9dQZF1DX274mITVX0K3',
#        'spotify:user:spotify:playlist:37i9dQZF1DXbKGrOUA30KN',
#        'spotify:user:spotify:playlist:37i9dQZF1DWUTqhVTO6wIG',
#        'spotify:user:spotify:playlist:37i9dQZF1DX0gbcr80GO9l',
#        'spotify:user:spotify:playlist:37i9dQZF1DWZSeAwtQzvji',
#        'spotify:user:spotify:playlist:37i9dQZF1DX4jP4eebSWR9'],
#       dtype=object)

# %%
debug = pd.read_csv('/Users/daria/Downloads/results-20190122-152339.csv')
debug.head()
# Out:
#                                           source_uri  avgskips  avglength  \
# 0  spotify:user:128735854:playlist:01sHpRa2WsC2vG...  0.113736   0.938275
# 1  spotify:user:mcamusic:playlist:28wfijoUpwrtwF7...  0.216804   0.912662
# 2  spotify:user:11145233736:playlist:3bwHB0zIWuNd...  0.049342   0.977311
# 3  spotify:user:jadybabyy:playlist:5MI8tSjJZlCcHK...  0.208635   0.874419
# 4  spotify:user:12179318102:playlist:2xSb6sk9xBub...  0.267304   0.862794
#
#     avgdisc    avgcol    avgret    avgsup  avgskipsb4
# 0  0.721400  0.045856  0.590152  0.673646    0.563140
# 1  0.629242  0.026486  0.517611  0.731629    0.641943
# 2  0.512274  0.011364  0.198715  0.910894    0.388865
# 3  0.722655  0.062787  0.626988  0.852220    0.511051
# 4  0.789301  0.058253  0.555398  0.571919    0.651347

# %%
debug[debug.avgskipsb4==0]
# Out:
# Empty DataFrame
# Columns: [source_uri, avgskips, avglength, avgdisc, avgcol, avgret, avgsup, avgskipsb4]
# Index: []
